# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
import json

# %%
from pathlib import Path
import sys
import os
import dask.bag as db

# %%
# Extract Only the AI , ML PAPERS
def extractArxivData(categories=['stat.ML','cs.AI'],year=None,raw_data_path="../data/raw/",save_extracted_filename="../data/processed/AI_ML.json"):
    """ This function extracts data for the given set of categories and save the data into the save_extracted_filename path """
    records=db.read_text(raw_data_path+"/*.json").map(lambda x:json.loads(x))
    docs = (records.filter(lambda x:any(ele in x['categories'] for ele in categories)==True))
    extract_latest_version=lambda x:x['versions'][-1]["created"]
    if year!=None:
        docs=docs.filter(lambda x:int(extract_latest_version(x).split(" ")[3])>=year)

    get_metadata = lambda x: {'id': x['id'],
                  'title': x['title'],
                  'category':x['categories'],
                  'abstract':x['abstract'],
                 'version':x['versions'][-1]['created'],
                         'doi':x["doi"],
                         'authors_parsed':x['authors_parsed']}
                        
    data=docs.map(get_metadata).to_dataframe().compute()

    ## Creating authors fields by joining first and last nmes in authors_parsed columns.
    data['authors']=data['authors_parsed'].apply(lambda authors:[(" ".join(author)).strip() for author in authors])

    print("Number of Records Extracted for Given Set of Categories ",data.shape[0])
    Path(os.path.dirname(save_extracted_filename)).mkdir(parents=True, exist_ok=True)
    data.to_json(save_extracted_filename,orient="records")
    return data

# %%
RAW_DATA_PATH="arxiv_data/"
## Collect data for Papers published in ['stat.ML','cs.AI'] since year 2015.
arxiv_df = extractArxivData(categories=['stat.ML','cs.AI'], year=2015, raw_data_path=RAW_DATA_PATH,save_extracted_filename="AI_ML_since2015.json")
# Out:
# Number of Records Extracted for Given Set of Categories  75996

# %%
arxiv_df
# Out:
#                id                                              title  \
# 0       0709.1667  Solving Constraint Satisfaction Problems throu...
# 1       0811.2551                         Modeling Cultural Dynamics
# 2       0812.0885  Elementary epistemological features of machine...
# 3       0812.4044   The Offset Tree for Learning with Partial Labels
# 4       0905.1424  Concept Stability for Constructing Taxonomies ...
# ...           ...                                                ...
# 75991  2111.12705  MixSyn: Learning Composition and Style for Mul...
# 75992  2111.12707  MHFormer: Multi-Hypothesis Transformer for 3D ...
# 75993  cs/0601132  A Study on the Global Convergence Time Complex...
# 75994  cs/0604010  Nearly optimal exploration-exploitation decisi...
# 75995  cs/0608037  Cascade hash tables: a series of multilevel do...
#
#                                              category  \
# 0      cs.AI cond-mat.dis-nn cond-mat.stat-mech cs.CC
# 1                                cs.MA cs.AI q-bio.NC
# 2                                               cs.AI
# 3                                         cs.LG cs.AI
# 4                           cs.CY cs.AI cs.SI stat.ML
# ...                                               ...
# 75991                                     cs.CV cs.AI
# 75992                               cs.CV cs.AI cs.LG
# 75993                                     cs.AI cs.NE
# 75994                                     cs.AI cs.LG
# 75995                                     cs.DS cs.AI
#
#                                                 abstract  \
# 0        Message passing algorithms have proved surpr...
# 1        EVOC (for EVOlution of Culture) is a compute...
# 2        Theoretical analysis of machine intelligence...
# 3        We present an algorithm, called the Offset T...
# 4        Owners of a web-site are often interested in...
# ...                                                  ...
# 75991    Synthetic images created by generative model...
# 75992    Estimating 3D human poses from monocular vid...
# 75993    The Estimation of Distribution Algorithm is ...
# 75994    While in general trading off exploration and...
# 75995    In this paper, the author proposes a series ...
#
#                              version   doi  \
# 0       Tue, 4 Jun 2019 11:43:45 GMT  None
# 1       Tue, 9 Jul 2019 20:25:22 GMT  None
# 2      Fri, 30 Jun 2017 14:10:03 GMT  None
# 3       Sun, 3 Apr 2016 21:41:38 GMT  None
# 4      Thu, 24 Nov 2016 19:25:12 GMT  None
# ...                              ...   ...
# 75991  Wed, 24 Nov 2021 18:58:34 GMT  None
# 75992  Wed, 24 Nov 2021 18:59:02 GMT  None
# 75993   Tue, 2 Apr 2019 10:03:57 GMT  None
# 75994   Mon, 4 Jun 2018 18:17:32 GMT  None
# 75995  Thu, 25 Jun 2015 14:25:38 GMT  None
#
#                                           authors_parsed  \
# 0      [[Montanari, Andrea, ], [Ricci-Tersenghi, Fede...
# 1                                    [[Gabora, Liane, ]]
# 2                                    [[Horvat, Marko, ]]
# 3           [[Beygelzimer, Alina, ], [Langford, John, ]]
# 4      [[Kuznetsov, Sergei O., ], [Ignatov, Dmitry I....
# ...                                                  ...
# 75991             [[Demir, Ilke, ], [Ciftci, Umur A., ]]
# 75992  [[Li, Wenhao, ], [Liu, Hong, ], [Tang, Hao, ],...
# 75993             [[Rastegar, R., ], [Meybodi, M. R., ]]
# 75994                       [[Dimitrakakis, Christos, ]]
# 75995                                  [[Li, Shaohua, ]]
#
#                                                  authors
# 0      [Montanari Andrea, Ricci-Tersenghi Federico, S...
# 1                                         [Gabora Liane]
# 2                                         [Horvat Marko]
# 3                     [Beygelzimer Alina, Langford John]
# 4               [Kuznetsov Sergei O., Ignatov Dmitry I.]
# ...                                                  ...
# 75991                       [Demir Ilke, Ciftci Umur A.]
# 75992  [Li Wenhao, Liu Hong, Tang Hao, Wang Pichao, V...
# 75993                       [Rastegar R., Meybodi M. R.]
# 75994                            [Dimitrakakis Christos]
# 75995                                       [Li Shaohua]
#
# [75996 rows x 8 columns]

# %%
arxiv_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75996 entries, 0 to 75995
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              75996 non-null  object
#  1   title           75996 non-null  object
#  2   category        75996 non-null  object
#  3   abstract        75996 non-null  object
#  4   version         75996 non-null  object
#  5   doi             9275 non-null   object
#  6   authors_parsed  75996 non-null  object
#  7   authors         75996 non-null  object
# dtypes: object(8)
# memory usage: 4.6+ MB

# %%
from itertools import combinations

# %%
arxiv_df['author_pairs'] = arxiv_df['authors'].apply(lambda x: list(combinations(x, 2)))
arxiv_df.head()
# Out:
#           id                                              title  \
# 0  0709.1667  Solving Constraint Satisfaction Problems throu...
# 1  0811.2551                         Modeling Cultural Dynamics
# 2  0812.0885  Elementary epistemological features of machine...
# 3  0812.4044   The Offset Tree for Learning with Partial Labels
# 4  0905.1424  Concept Stability for Constructing Taxonomies ...
#
#                                          category  \
# 0  cs.AI cond-mat.dis-nn cond-mat.stat-mech cs.CC
# 1                            cs.MA cs.AI q-bio.NC
# 2                                           cs.AI
# 3                                     cs.LG cs.AI
# 4                       cs.CY cs.AI cs.SI stat.ML
#
#                                             abstract  \
# 0    Message passing algorithms have proved surpr...
# 1    EVOC (for EVOlution of Culture) is a compute...
# 2    Theoretical analysis of machine intelligence...
# 3    We present an algorithm, called the Offset T...
# 4    Owners of a web-site are often interested in...
#
#                          version   doi  \
# 0   Tue, 4 Jun 2019 11:43:45 GMT  None
# 1   Tue, 9 Jul 2019 20:25:22 GMT  None
# 2  Fri, 30 Jun 2017 14:10:03 GMT  None
# 3   Sun, 3 Apr 2016 21:41:38 GMT  None
# 4  Thu, 24 Nov 2016 19:25:12 GMT  None
#
#                                       authors_parsed  \
# 0  [[Montanari, Andrea, ], [Ricci-Tersenghi, Fede...
# 1                                [[Gabora, Liane, ]]
# 2                                [[Horvat, Marko, ]]
# 3       [[Beygelzimer, Alina, ], [Langford, John, ]]
# 4  [[Kuznetsov, Sergei O., ], [Ignatov, Dmitry I....
#
#                                              authors  \
# 0  [Montanari Andrea, Ricci-Tersenghi Federico, S...
# 1                                     [Gabora Liane]
# 2                                     [Horvat Marko]
# 3                 [Beygelzimer Alina, Langford John]
# 4           [Kuznetsov Sergei O., Ignatov Dmitry I.]
#
#                                         author_pairs
# 0  [(Montanari Andrea, Ricci-Tersenghi Federico),...
# 1                                                 []
# 2                                                 []
# 3               [(Beygelzimer Alina, Langford John)]
# 4         [(Kuznetsov Sergei O., Ignatov Dmitry I.)]

# %%
ai_authors = [author for author_list in arxiv_df['authors'] for author in author_list ]
len(ai_authors)
# Out:
# 286021

# %%
from collections import Counter

# %%
paper_count_by_author = Counter(ai_authors)

# %%
paper_count_by_author.most_common(5)
# Out:
# [('Bengio Yoshua', 216),
#  ('Levine Sergey', 216),
#  ('Abbeel Pieter', 162),
#  ('Jordan Michael I.', 157),
#  ('Schölkopf Bernhard', 139)]

# %%
len(paper_count_by_author.keys())
# Out:
# 116477

# %%
nodes_to_keep = {key for key, value in paper_count_by_author.items() if value >= 10}
len(nodes_to_keep)
# Out:
# 4297

# %% [markdown]
# ## Build CoAuthor Graph

# %%
author_edge_list = [author_pair for author_pair_list in arxiv_df['author_pairs'] for author_pair in author_pair_list]
author_edge_list
# Out:
# [('Montanari Andrea', 'Ricci-Tersenghi Federico'),
#  ('Montanari Andrea', 'Semerjian Guilhem'),
#  ('Ricci-Tersenghi Federico', 'Semerjian Guilhem'),
#  ('Beygelzimer Alina', 'Langford John'),
#  ('Kuznetsov Sergei O.', 'Ignatov Dmitry I.'),
#  ('Blume Lawrence', 'Easley David'),
#  ('Blume Lawrence', 'Halpern Joseph Y.'),
#  ('Easley David', 'Halpern Joseph Y.'),
#  ('Kakade Sham M.', 'Shamir Ohad'),
#  ('Kakade Sham M.', 'Sridharan Karthik'),
#  ('Kakade Sham M.', 'Tewari Ambuj'),
#  ('Shamir Ohad', 'Sridharan Karthik'),
#  ('Shamir Ohad', 'Tewari Ambuj'),
#  ('Sridharan Karthik', 'Tewari Ambuj'),
#  ('Lunagómez Simón', 'Mukherjee Sayan'),
#  ('Lunagómez Simón', 'Wolpert Robert L.'),
#  ('Lunagómez Simón', 'Airoldi Edoardo M.'),
#  ('Mukherjee Sayan', 'Wolpert Robert L.'),
#  ('Mukherjee Sayan', 'Airoldi Edoardo M.'),
#  ('Wolpert Robert L.', 'Airoldi Edoardo M.'),
#  ('DiPaola Steve', 'Gabora Liane'),
#  ('Mossel Elchanan', 'Olsman Noah'),
#  ('Mossel Elchanan', 'Tamuz Omer'),
#  ('Olsman Noah', 'Tamuz Omer'),
#  ('Golovin Daniel', 'Krause Andreas'),
#  ('Ackerman Nathanael L.', 'Freer Cameron E.'),
#  ('Ackerman Nathanael L.', 'Roy Daniel M.'),
#  ('Freer Cameron E.', 'Roy Daniel M.'),
#  ('Parthasarathy Dhruv', 'Shah Devavrat'),
#  ('Parthasarathy Dhruv', 'Zaman Tauhid'),
#  ('Shah Devavrat', 'Zaman Tauhid'),
#  ('Koltchinskii Vladimir', 'Tsybakov Alexandre B.'),
#  ('Koltchinskii Vladimir', 'Lounici Karim'),
#  ('Tsybakov Alexandre B.', 'Lounici Karim'),
#  ('Chen Yudong', 'Xu Huan'),
#  ('Chen Yudong', 'Caramanis Constantine'),
#  ('Chen Yudong', 'Sanghavi Sujay'),
#  ('Xu Huan', 'Caramanis Constantine'),
#  ('Xu Huan', 'Sanghavi Sujay'),
#  ('Caramanis Constantine', 'Sanghavi Sujay'),
#  ('Langovoy Mikhail A.', 'Wittich Olaf'),
#  ('Langovoy Mikhail A.', 'Davies Patrick Laurie'),
#  ('Wittich Olaf', 'Davies Patrick Laurie'),
#  ('Gerchinovitz Sébastien  DMA, CLASSIC', 'Yu Jia Yuan'),
#  ('Cvetkovski Andrej', 'Crovella Mark'),
#  ('Baxter Jonathan', 'Bartlett Peter L.'),
#  ('Baxter J.', 'Bartlett P. L.'),
#  ('Baxter J.', 'Weaver L.'),
#  ('Bartlett P. L.', 'Weaver L.'),
#  ('McDonald Daniel J.', 'Shalizi Cosma Rohilla'),
#  ('Gabora Liane', 'Ranjan Apara'),
#  ('Kolchinsky Artemy', 'Rocha Luis M.'),
#  ('Álvarez Mauricio A.', 'Luengo David'),
#  ('Álvarez Mauricio A.', 'Lawrence Neil D.'),
#  ('Luengo David', 'Lawrence Neil D.'),
#  ('Lopes Miles E.', 'Jacob Laurent J.'),
#  ('Lopes Miles E.', 'Wainwright Martin J.'),
#  ('Jacob Laurent J.', 'Wainwright Martin J.'),
#  ('Bouvrie Jake', 'Hamzi Boumediene'),
#  ('Camps Rosa', 'Mora Xavier'),
#  ('Camps Rosa', 'Saumell Laia'),
#  ('Mora Xavier', 'Saumell Laia'),
#  ('Rossi Roberto', 'Hnich Brahim'),
#  ('Rossi Roberto', 'Tarim S. Armagan'),
#  ('Rossi Roberto', 'Prestwich Steven'),
#  ('Hnich Brahim', 'Tarim S. Armagan'),
#  ('Hnich Brahim', 'Prestwich Steven'),
#  ('Tarim S. Armagan', 'Prestwich Steven'),
#  ('Preen Richard J.', 'Bull Larry'),
#  ('Sutherland Danica J.', 'Xiong Liang'),
#  ('Sutherland Danica J.', 'Póczos Barnabás'),
#  ('Sutherland Danica J.', 'Schneider Jeff'),
#  ('Xiong Liang', 'Póczos Barnabás'),
#  ('Xiong Liang', 'Schneider Jeff'),
#  ('Póczos Barnabás', 'Schneider Jeff'),
#  ('Yamada Makoto', 'Jitkrittum Wittawat'),
#  ('Yamada Makoto', 'Sigal Leonid'),
#  ('Yamada Makoto', 'Xing Eric P.'),
#  ('Yamada Makoto', 'Sugiyama Masashi'),
#  ('Jitkrittum Wittawat', 'Sigal Leonid'),
#  ('Jitkrittum Wittawat', 'Xing Eric P.'),
#  ('Jitkrittum Wittawat', 'Sugiyama Masashi'),
#  ('Sigal Leonid', 'Xing Eric P.'),
#  ('Sigal Leonid', 'Sugiyama Masashi'),
#  ('Xing Eric P.', 'Sugiyama Masashi'),
#  ('Venkataramanan Ramji', 'Joseph Antony'),
#  ('Venkataramanan Ramji', 'Tatikonda Sekhar'),
#  ('Joseph Antony', 'Tatikonda Sekhar'),
#  ('Schulte Phillip J.', 'Tsiatis Anastasios A.'),
#  ('Schulte Phillip J.', 'Laber Eric B.'),
#  ('Schulte Phillip J.', 'Davidian Marie'),
#  ('Tsiatis Anastasios A.', 'Laber Eric B.'),
#  ('Tsiatis Anastasios A.', 'Davidian Marie'),
#  ('Laber Eric B.', 'Davidian Marie'),
#  ('Ndour Cheikh', 'Diop Aliou'),
#  ('Ndour Cheikh', 'Dossou-Gbété Simplice'),
#  ('Diop Aliou', 'Dossou-Gbété Simplice'),
#  ('Liu Weidong', 'Luo Xi'),
#  ('Bouvrie Jake', 'Hamzi Boumediene'),
#  ('Huszár Ferenc', 'Duvenaud David'),
#  ('Quinn Christopher J.', 'Kiyavash Negar'),
#  ('Quinn Christopher J.', 'Coleman Todd P.'),
#  ('Kiyavash Negar', 'Coleman Todd P.'),
#  ('Rohe Karl', 'Qin Tai'),
#  ('Rohe Karl', 'Yu Bin'),
#  ('Qin Tai', 'Yu Bin'),
#  ('Liberatore Paolo', 'Schaerf Marco'),
#  ('Kadri Hachem  INRIA Lille - Nord Europe',
#   'Ghavamzadeh Mohammad  INRIA\n  Lille - Nord Europe'),
#  ('Kadri Hachem  INRIA Lille - Nord Europe',
#   'Preux Philippe  INRIA Lille - Nord Europe'),
#  ('Ghavamzadeh Mohammad  INRIA\n  Lille - Nord Europe',
#   'Preux Philippe  INRIA Lille - Nord Europe'),
#  ('Ozay Mete', 'Öztekin Ilke'),
#  ('Ozay Mete', 'Öztekin Uygar'),
#  ('Ozay Mete', 'Vural Fatos T. Yarman'),
#  ('Öztekin Ilke', 'Öztekin Uygar'),
#  ('Öztekin Ilke', 'Vural Fatos T. Yarman'),
#  ('Öztekin Uygar', 'Vural Fatos T. Yarman'),
#  ('Sodhi Balwinder', 'T. Prabhakar V'),
#  ('Chen Yudong', 'Caramanis Constantine'),
#  ('Krueger Tammo', 'Panknin Danny'),
#  ('Krueger Tammo', 'Braun Mikio'),
#  ('Panknin Danny', 'Braun Mikio'),
#  ('Wang Chong', 'Blei David'),
#  ('Wang Chong', 'Heckerman David'),
#  ('Blei David', 'Heckerman David'),
#  ('Honorio Jean', 'Ortiz Luis'),
#  ('Vanhatalo Jarno', 'Riihimäki Jaakko'),
#  ('Vanhatalo Jarno', 'Hartikainen Jouni'),
#  ('Vanhatalo Jarno', 'Jylänki Pasi'),
#  ('Vanhatalo Jarno', 'Tolvanen Ville'),
#  ('Vanhatalo Jarno', 'Vehtari Aki'),
#  ('Riihimäki Jaakko', 'Hartikainen Jouni'),
#  ('Riihimäki Jaakko', 'Jylänki Pasi'),
#  ('Riihimäki Jaakko', 'Tolvanen Ville'),
#  ('Riihimäki Jaakko', 'Vehtari Aki'),
#  ('Hartikainen Jouni', 'Jylänki Pasi'),
#  ('Hartikainen Jouni', 'Tolvanen Ville'),
#  ('Hartikainen Jouni', 'Vehtari Aki'),
#  ('Jylänki Pasi', 'Tolvanen Ville'),
#  ('Jylänki Pasi', 'Vehtari Aki'),
#  ('Tolvanen Ville', 'Vehtari Aki'),
#  ('Flynn Cheryl J.', 'Perry Patrick O.'),
#  ('Deisenroth Marc Peter', 'Mohamed Shakir'),
#  ('Hanneke Steve', 'Yang Liu'),
#  ('Honorio Jean', 'Jaakkola Tommi'),
#  ('Honorio Jean', 'Samaras Dimitris'),
#  ('Jaakkola Tommi', 'Samaras Dimitris'),
#  ('Chadha Aman', 'Mallik Sushmit'),
#  ('Chadha Aman', 'Johar Ravdeep'),
#  ('Mallik Sushmit', 'Johar Ravdeep'),
#  ('Fishkind Donniell E.', 'Adali Sancar'),
#  ('Fishkind Donniell E.', 'Patsolic Heather G.'),
#  ('Fishkind Donniell E.', 'Meng Lingyao'),
#  ('Fishkind Donniell E.', 'Singh Digvijay'),
#  ('Fishkind Donniell E.', 'Lyzinski Vince'),
#  ('Fishkind Donniell E.', 'Priebe Carey E.'),
#  ('Adali Sancar', 'Patsolic Heather G.'),
#  ('Adali Sancar', 'Meng Lingyao'),
#  ('Adali Sancar', 'Singh Digvijay'),
#  ('Adali Sancar', 'Lyzinski Vince'),
#  ('Adali Sancar', 'Priebe Carey E.'),
#  ('Patsolic Heather G.', 'Meng Lingyao'),
#  ('Patsolic Heather G.', 'Singh Digvijay'),
#  ('Patsolic Heather G.', 'Lyzinski Vince'),
#  ('Patsolic Heather G.', 'Priebe Carey E.'),
#  ('Meng Lingyao', 'Singh Digvijay'),
#  ('Meng Lingyao', 'Lyzinski Vince'),
#  ('Meng Lingyao', 'Priebe Carey E.'),
#  ('Singh Digvijay', 'Lyzinski Vince'),
#  ('Singh Digvijay', 'Priebe Carey E.'),
#  ('Lyzinski Vince', 'Priebe Carey E.'),
#  ('Delalleau Olivier', 'Courville Aaron'),
#  ('Delalleau Olivier', 'Bengio Yoshua'),
#  ('Courville Aaron', 'Bengio Yoshua'),
#  ('Bahmani Sohail', 'Boufounos Petros T.'),
#  ('Bahmani Sohail', 'Raj Bhiksha'),
#  ('Boufounos Petros T.', 'Raj Bhiksha'),
#  ('Negahban Sahand', 'Oh Sewoong'),
#  ('Negahban Sahand', 'Shah Devavrat'),
#  ('Oh Sewoong', 'Shah Devavrat'),
#  ('Grandvalet Yves', 'Chiquet Julien'),
#  ('Grandvalet Yves', 'Ambroise Christophe'),
#  ('Chiquet Julien', 'Ambroise Christophe'),
#  ('Chen Yudong', 'Sanghavi Sujay'),
#  ('Chen Yudong', 'Xu Huan'),
#  ('Sanghavi Sujay', 'Xu Huan'),
#  ('Miao Weimin', 'Pan Shaohua'),
#  ('Miao Weimin', 'Sun Defeng'),
#  ('Pan Shaohua', 'Sun Defeng'),
#  ('Fan Jianqing', 'Xue Lingzhou'),
#  ('Fan Jianqing', 'Zou Hui'),
#  ('Xue Lingzhou', 'Zou Hui'),
#  ('Beleites Claudia', 'Neugebauer Ute'),
#  ('Beleites Claudia', 'Bocklitz Thomas'),
#  ('Beleites Claudia', 'Krafft Christoph'),
#  ('Beleites Claudia', 'Popp Jürgen'),
#  ('Neugebauer Ute', 'Bocklitz Thomas'),
#  ('Neugebauer Ute', 'Krafft Christoph'),
#  ('Neugebauer Ute', 'Popp Jürgen'),
#  ('Bocklitz Thomas', 'Krafft Christoph'),
#  ('Bocklitz Thomas', 'Popp Jürgen'),
#  ('Krafft Christoph', 'Popp Jürgen'),
#  ('Rambhatla Sirisha', 'Haupt Jarvis D.'),
#  ('McDonald Daniel J.', 'Shalizi Cosma Rohilla'),
#  ('McDonald Daniel J.', 'Schervish Mark'),
#  ('Shalizi Cosma Rohilla', 'Schervish Mark'),
#  ('Masnadi-Shirazi Hamed', 'Vasconcelos Nuno'),
#  ('Masnadi-Shirazi Hamed', 'Iranmehr Arya'),
#  ('Vasconcelos Nuno', 'Iranmehr Arya'),
#  ('Belanich Joshua', 'Ortiz Luis E.'),
#  ('Sabato Sivan', 'Shalev-Shwartz Shai'),
#  ('Sabato Sivan', 'Srebro Nathan'),
#  ('Sabato Sivan', 'Hsu Daniel'),
#  ('Sabato Sivan', 'Zhang Tong'),
#  ('Shalev-Shwartz Shai', 'Srebro Nathan'),
#  ('Shalev-Shwartz Shai', 'Hsu Daniel'),
#  ('Shalev-Shwartz Shai', 'Zhang Tong'),
#  ('Srebro Nathan', 'Hsu Daniel'),
#  ('Srebro Nathan', 'Zhang Tong'),
#  ('Hsu Daniel', 'Zhang Tong'),
#  ('Richtárik Peter', 'Jahani Majid'),
#  ('Richtárik Peter', 'Ahipaşaoğlu Selin Damla'),
#  ('Richtárik Peter', 'Takáč Martin'),
#  ('Jahani Majid', 'Ahipaşaoğlu Selin Damla'),
#  ('Jahani Majid', 'Takáč Martin'),
#  ('Ahipaşaoğlu Selin Damla', 'Takáč Martin'),
#  ('Kadie Carl', 'Meek Christopher'),
#  ('Kadie Carl', 'Heckerman David'),
#  ('Meek Christopher', 'Heckerman David'),
#  ('Shani Guy', 'Brafman Ronen I.'),
#  ('Shani Guy', 'Heckerman David'),
#  ('Brafman Ronen I.', 'Heckerman David'),
#  ('Wang Ziyu', 'Hutter Frank'),
#  ('Wang Ziyu', 'Zoghi Masrour'),
#  ('Wang Ziyu', 'Matheson David'),
#  ('Wang Ziyu', 'de Freitas Nando'),
#  ('Hutter Frank', 'Zoghi Masrour'),
#  ('Hutter Frank', 'Matheson David'),
#  ('Hutter Frank', 'de Freitas Nando'),
#  ('Zoghi Masrour', 'Matheson David'),
#  ('Zoghi Masrour', 'de Freitas Nando'),
#  ('Matheson David', 'de Freitas Nando'),
#  ('Fishkind Donniell E.', 'Shen Cencheng'),
#  ('Fishkind Donniell E.', 'Park Youngser'),
#  ('Fishkind Donniell E.', 'Priebe Carey E.'),
#  ('Shen Cencheng', 'Park Youngser'),
#  ('Shen Cencheng', 'Priebe Carey E.'),
#  ('Park Youngser', 'Priebe Carey E.'),
#  ('Zhang Xiaowang', 'Wang Kewen'),
#  ('Zhang Xiaowang', 'Wang Zhe'),
#  ('Zhang Xiaowang', 'Ma Yue'),
#  ('Zhang Xiaowang', 'Qi Guilin'),
#  ('Wang Kewen', 'Wang Zhe'),
#  ('Wang Kewen', 'Ma Yue'),
#  ('Wang Kewen', 'Qi Guilin'),
#  ('Wang Zhe', 'Ma Yue'),
#  ('Wang Zhe', 'Qi Guilin'),
#  ('Ma Yue', 'Qi Guilin'),
#  ('Kearns Michael', 'Littman Michael L.'),
#  ('Kearns Michael', 'Singh Satinder'),
#  ('Littman Michael L.', 'Singh Satinder'),
#  ('Yang Eunho', 'Ravikumar Pradeep'),
#  ('Yang Eunho', 'Allen Genevera I.'),
#  ('Yang Eunho', 'Liu Zhandong'),
#  ('Ravikumar Pradeep', 'Allen Genevera I.'),
#  ('Ravikumar Pradeep', 'Liu Zhandong'),
#  ('Allen Genevera I.', 'Liu Zhandong'),
#  ('Garber Dan', 'Hazan Elad'),
#  ('Lin Tianyi', 'Ma Shiqian'),
#  ('Lin Tianyi', 'Zhang Shuzhong'),
#  ('Ma Shiqian', 'Zhang Shuzhong'),
#  ('Chickering David Maxwell', 'Heckerman David'),
#  ('Geiger Dan', 'Heckerman David'),
#  ('Heckerman David', 'Horvitz Eric J.'),
#  ('Meila Marina', 'Heckerman David'),
#  ('Thiesson Bo', 'Meek Christopher'),
#  ('Thiesson Bo', 'Chickering David Maxwell'),
#  ('Thiesson Bo', 'Heckerman David'),
#  ('Meek Christopher', 'Chickering David Maxwell'),
#  ('Meek Christopher', 'Heckerman David'),
#  ('Chickering David Maxwell', 'Heckerman David'),
#  ('Chickering David Maxwell', 'Heckerman David'),
#  ('Chickering David Maxwell', 'Meek Christopher'),
#  ('Heckerman David', 'Meek Christopher'),
#  ('Meek Christopher', 'Heckerman David'),
#  ('Horvat Marko', 'Grbin Anton'),
#  ('Horvat Marko', 'Gledec Gordan'),
#  ('Grbin Anton', 'Gledec Gordan'),
#  ('Gottlieb Lee-Ad', 'Kontorovich Aryeh'),
#  ('Gottlieb Lee-Ad', 'Krauthgamer Robert'),
#  ('Kontorovich Aryeh', 'Krauthgamer Robert'),
#  ('Breese John S.', 'Heckerman David'),
#  ('Chickering David Maxwell', 'Heckerman David'),
#  ('Geiger Dan', 'Heckerman David'),
#  ('Geiger Dan', 'Meek Christopher'),
#  ('Heckerman David', 'Meek Christopher'),
#  ('Heckerman David', 'Shachter Ross D.'),
#  ('Heckerman David', 'Geiger Dan'),
#  ('Françoisse Kevin', 'Kivimäki Ilkka'),
#  ('Françoisse Kevin', 'Mantrach Amin'),
#  ('Françoisse Kevin', 'Rossi Fabrice'),
#  ('Françoisse Kevin', 'Saerens Marco'),
#  ('Kivimäki Ilkka', 'Mantrach Amin'),
#  ('Kivimäki Ilkka', 'Rossi Fabrice'),
#  ('Kivimäki Ilkka', 'Saerens Marco'),
#  ('Mantrach Amin', 'Rossi Fabrice'),
#  ('Mantrach Amin', 'Saerens Marco'),
#  ('Rossi Fabrice', 'Saerens Marco'),
#  ('Geiger Dan', 'Heckerman David'),
#  ('Heckerman David', 'Breese John S.'),
#  ('Heckerman David', 'Geiger Dan'),
#  ('Heckerman David', 'Chickering David Maxwell'),
#  ('Geiger Dan', 'Chickering David Maxwell'),
#  ('Heckerman David', 'Shachter Ross D.'),
#  ('Cai T. Tony', 'Zhou Wen-Xin'),
#  ('Blanchard Gilles', 'Flaska Marek'),
#  ('Blanchard Gilles', 'Handy Gregory'),
#  ('Blanchard Gilles', 'Pozzi Sara'),
#  ('Blanchard Gilles', 'Scott Clayton'),
#  ('Flaska Marek', 'Handy Gregory'),
#  ('Flaska Marek', 'Pozzi Sara'),
#  ('Flaska Marek', 'Scott Clayton'),
#  ('Handy Gregory', 'Pozzi Sara'),
#  ('Handy Gregory', 'Scott Clayton'),
#  ('Pozzi Sara', 'Scott Clayton'),
#  ('Heckerman David', 'Shwe Michael'),
#  ('Geiger Dan', 'Heckerman David'),
#  ('Lim Chinghway', 'Yu Bin'),
#  ('Baldassarre Luca', 'Bhan Nirav'),
#  ('Baldassarre Luca', 'Cevher Volkan'),
#  ('Baldassarre Luca', 'Kyrillidis Anastasios'),
#  ('Baldassarre Luca', 'Satpathi Siddhartha'),
#  ('Bhan Nirav', 'Cevher Volkan'),
#  ('Bhan Nirav', 'Kyrillidis Anastasios'),
#  ('Bhan Nirav', 'Satpathi Siddhartha'),
#  ('Cevher Volkan', 'Kyrillidis Anastasios'),
#  ('Cevher Volkan', 'Satpathi Siddhartha'),
#  ('Kyrillidis Anastasios', 'Satpathi Siddhartha'),
#  ('Tomal Jabed H.', 'Welch William J.'),
#  ('Tomal Jabed H.', 'Zamar Ruben H.'),
#  ('Welch William J.', 'Zamar Ruben H.'),
#  ('Isaac Yoann', 'Barthélemy Quentin'),
#  ('Isaac Yoann', 'Atif Jamal'),
#  ('Isaac Yoann', 'Gouy-Pailler Cédric'),
#  ('Isaac Yoann', 'Sebag Michèle'),
#  ('Barthélemy Quentin', 'Atif Jamal'),
#  ('Barthélemy Quentin', 'Gouy-Pailler Cédric'),
#  ('Barthélemy Quentin', 'Sebag Michèle'),
#  ('Atif Jamal', 'Gouy-Pailler Cédric'),
#  ('Atif Jamal', 'Sebag Michèle'),
#  ('Gouy-Pailler Cédric', 'Sebag Michèle'),
#  ('Geiger Dan', 'Heckerman David'),
#  ('Heckerman David', 'Horvitz Eric J.'),
#  ('Heckerman David', 'Middleton Blackford'),
#  ('Horvitz Eric J.', 'Middleton Blackford'),
#  ('Aksoylar Cem', 'Atia George'),
#  ('Aksoylar Cem', 'Saligrama Venkatesh'),
#  ('Atia George', 'Saligrama Venkatesh'),
#  ('Karaaslan Faruk', 'Cagman Naim'),
#  ('Karaaslan Faruk', 'Yilmaz Saban'),
#  ('Cagman Naim', 'Yilmaz Saban'),
#  ('Heckerman David', 'Horvitz Eric J.'),
#  ('Geiger Dan', 'Heckerman David'),
#  ('Cheng Jie', 'Li Tianxi'),
#  ('Cheng Jie', 'Levina Elizaveta'),
#  ('Cheng Jie', 'Zhu Ji'),
#  ('Li Tianxi', 'Levina Elizaveta'),
#  ('Li Tianxi', 'Zhu Ji'),
#  ('Levina Elizaveta', 'Zhu Ji'),
#  ('Gaynor Sheila', 'Bair Eric'),
#  ('Dasgupta Sayan', 'Goldberg Yair'),
#  ('Dasgupta Sayan', 'Kosorok Michael'),
#  ('Goldberg Yair', 'Kosorok Michael'),
#  ('Chen Jianhui', 'Yang Tianbao'),
#  ('Chen Jianhui', 'Lin Qihang'),
#  ('Chen Jianhui', 'Zhang Lijun'),
#  ('Chen Jianhui', 'Chang Yi'),
#  ('Yang Tianbao', 'Lin Qihang'),
#  ('Yang Tianbao', 'Zhang Lijun'),
#  ('Yang Tianbao', 'Chang Yi'),
#  ('Lin Qihang', 'Zhang Lijun'),
#  ('Lin Qihang', 'Chang Yi'),
#  ('Zhang Lijun', 'Chang Yi'),
#  ('Zhen Liangli', 'Yi Zhang'),
#  ('Zhen Liangli', 'Peng Xi'),
#  ('Zhen Liangli', 'Peng Dezhong'),
#  ('Yi Zhang', 'Peng Xi'),
#  ('Yi Zhang', 'Peng Dezhong'),
#  ('Peng Xi', 'Peng Dezhong'),
#  ('Barbu Adrian', 'Wu Tianfu'),
#  ('Barbu Adrian', 'Wu Ying Nian'),
#  ('Wu Tianfu', 'Wu Ying Nian'),
#  ('Liu Han', 'Wang Lie'),
#  ('Liu Han', 'Zhao Tuo'),
#  ('Wang Lie', 'Zhao Tuo'),
#  ('Loh Po-Ling', 'Wainwright Martin J.'),
#  ('Cseke Botond', 'Mangion Andrew Zammit'),
#  ('Cseke Botond', 'Heskes Tom'),
#  ('Cseke Botond', 'Sanguinetti Guido'),
#  ('Mangion Andrew Zammit', 'Heskes Tom'),
#  ('Mangion Andrew Zammit', 'Sanguinetti Guido'),
#  ('Heskes Tom', 'Sanguinetti Guido'),
#  ('Wegkamp Marten', 'Zhao Yue'),
#  ('Han Fang', 'Liu Han'),
#  ('Netrapalli Praneeth', 'Jain Prateek'),
#  ('Netrapalli Praneeth', 'Sanghavi Sujay'),
#  ('Jain Prateek', 'Sanghavi Sujay'),
#  ('Wang Yuyi', 'Ramon Jan'),
#  ('Wang Yuyi', 'Guo Zheng-Chu'),
#  ('Ramon Jan', 'Guo Zheng-Chu'),
#  ('Balcan Maria Florina', 'Ehrlich Steven'),
#  ('Balcan Maria Florina', 'Liang Yingyu'),
#  ('Ehrlich Steven', 'Liang Yingyu'),
#  ('Nemeth Christopher', 'Fearnhead Paul'),
#  ('Nemeth Christopher', 'Mihaylova Lyudmila'),
#  ('Fearnhead Paul', 'Mihaylova Lyudmila'),
#  ('Dimitrakakis Christos', 'Nelson Blaine'),
#  ('Dimitrakakis Christos', 'Zhang and Zuhe'),
#  ('Dimitrakakis Christos', 'Mitrokotsa Aikaterini'),
#  ('Dimitrakakis Christos', 'Rubinstein Benjamin'),
#  ('Nelson Blaine', 'Zhang and Zuhe'),
#  ('Nelson Blaine', 'Mitrokotsa Aikaterini'),
#  ('Nelson Blaine', 'Rubinstein Benjamin'),
#  ('Zhang and Zuhe', 'Mitrokotsa Aikaterini'),
#  ('Zhang and Zuhe', 'Rubinstein Benjamin'),
#  ('Mitrokotsa Aikaterini', 'Rubinstein Benjamin'),
#  ('Singer Amit', 'Wu Hau-tieng'),
#  ('Lang Jérôme', 'Maudet Nicolas'),
#  ('Lang Jérôme', 'Polukarov Maria'),
#  ('Lang Jérôme', 'Cohen-Hadria Alice'),
#  ('Maudet Nicolas', 'Polukarov Maria'),
#  ('Maudet Nicolas', 'Cohen-Hadria Alice'),
#  ('Polukarov Maria', 'Cohen-Hadria Alice'),
#  ('Vepakomma Praneeth', 'Elgammal Ahmed'),
#  ('Prashanth L. A.', 'Korda Nathaniel'),
#  ('Prashanth L. A.', 'Munos Rémi'),
#  ('Korda Nathaniel', 'Munos Rémi'),
#  ('Krauthgamer Robert', 'Nadler Boaz'),
#  ('Krauthgamer Robert', 'Vilenchik Dan'),
#  ('Nadler Boaz', 'Vilenchik Dan'),
#  ('Lyne Anne-Marie', 'Girolami Mark'),
#  ('Lyne Anne-Marie', 'Atchadé Yves'),
#  ('Lyne Anne-Marie', 'Strathmann Heiko'),
#  ('Lyne Anne-Marie', 'Simpson Daniel'),
#  ('Girolami Mark', 'Atchadé Yves'),
#  ('Girolami Mark', 'Strathmann Heiko'),
#  ('Girolami Mark', 'Simpson Daniel'),
#  ('Atchadé Yves', 'Strathmann Heiko'),
#  ('Atchadé Yves', 'Simpson Daniel'),
#  ('Strathmann Heiko', 'Simpson Daniel'),
#  ('Wang Zhaoran', 'Liu Han'),
#  ('Wang Zhaoran', 'Zhang Tong'),
#  ('Liu Han', 'Zhang Tong'),
#  ('Subedi Sanjeena', 'McNicholas Paul D.'),
#  ('Mallat Stéphane', 'Waldspurger Irène'),
#  ('Lu Zhaosong', 'Xiao Lin'),
#  ('Sykulski Adam M.', 'Olhede Sofia C.'),
#  ('Sykulski Adam M.', 'Lilly Jonathan M.'),
#  ('Sykulski Adam M.', 'Early Jeffrey J.'),
#  ('Olhede Sofia C.', 'Lilly Jonathan M.'),
#  ('Olhede Sofia C.', 'Early Jeffrey J.'),
#  ('Lilly Jonathan M.', 'Early Jeffrey J.'),
#  ('Lampert Thomas A.', 'Stumpf André'),
#  ('Lampert Thomas A.', 'Gançarski Pierre'),
#  ('Stumpf André', 'Gançarski Pierre'),
#  ('Žitnik Marinka', 'Zupan Blaž'),
#  ('Hsu Daniel', 'Sabato Sivan'),
#  ('Vrbik Irene', 'McNicholas Paul D.'),
#  ('Kanade Varun', 'Mossel Elchanan'),
#  ('Wen Zheng', 'Van Roy Benjamin'),
#  ('Heckel Reinhard', 'Bölcskei Helmut'),
#  ('Maathuis Marloes H.', 'Colombo Diego'),
#  ('Hall Eric C.', 'Willett Rebecca M.'),
#  ('Reverdy Paul', 'Srivastava Vaibhav'),
#  ('Reverdy Paul', 'Leonard Naomi E.'),
#  ('Srivastava Vaibhav', 'Leonard Naomi E.'),
#  ('Chen Mengjie', 'Gao Chao'),
#  ('Chen Mengjie', 'Zhao Hongyu'),
#  ('Gao Chao', 'Zhao Hongyu'),
#  ('Awasthi Pranjal', 'Balcan Maria Florina'),
#  ('Awasthi Pranjal', 'Long Philip M.'),
#  ('Balcan Maria Florina', 'Long Philip M.'),
#  ('Mukhopadhyay Subhadeep', 'Parzen Emanuel'),
#  ('Homrighausen Darren', 'McDonald Daniel J.'),
#  ('Tanaka Kentaro', 'Miyakawa Masami'),
#  ('Shah Rajen D.', 'Meinshausen Nicolai'),
#  ('Zach Christopher', 'Häne Christian'),
#  ('Preen Richard J.', 'Bull Larry'),
#  ('Martino L.', 'Casarin R.'),
#  ('Martino L.', 'Leisen F.'),
#  ('Martino L.', 'Luengo D.'),
#  ('Casarin R.', 'Leisen F.'),
#  ('Casarin R.', 'Luengo D.'),
#  ('Leisen F.', 'Luengo D.'),
#  ('Bagnara Roberto', 'Carlier Matthieu'),
#  ('Bagnara Roberto', 'Gori Roberta'),
#  ('Bagnara Roberto', 'Gotlieb Arnaud'),
#  ('Carlier Matthieu', 'Gori Roberta'),
#  ('Carlier Matthieu', 'Gotlieb Arnaud'),
#  ('Gori Roberta', 'Gotlieb Arnaud'),
#  ('Borgwardt Steffen', 'Brieden Andreas'),
#  ('Borgwardt Steffen', 'Gritzmann Peter'),
#  ('Brieden Andreas', 'Gritzmann Peter'),
#  ('Fithian William', 'Mazumder Rahul'),
#  ('Benzmüller Christoph', 'Paleo Bruno Woltzenlogel'),
#  ('Tekin Cem', 'van der Schaar Mihaela'),
#  ('Shi Ziqiang', 'Liu Rujie'),
#  ('Gabora Liane', 'DiPaola Steve'),
#  ('Zhang Zhihua', 'Li Jin'),
#  ('Morris Katherine', 'McNicholas Paul D.'),
#  ('Huang Furong', 'Niranjan U. N.'),
#  ('Huang Furong', 'Hakeem Mohammad Umar'),
#  ('Huang Furong', 'Anandkumar Animashree'),
#  ('Niranjan U. N.', 'Hakeem Mohammad Umar'),
#  ('Niranjan U. N.', 'Anandkumar Animashree'),
#  ('Hakeem Mohammad Umar', 'Anandkumar Animashree'),
#  ('Dzhafarov Ehtibar N.', 'Kujala Janne V.'),
#  ('Wang Yu-Xiang', 'Xu Huan'),
#  ('Schmidt Mark  SIERRA, LIENS', 'Roux Nicolas Le  SIERRA, LIENS'),
#  ('Schmidt Mark  SIERRA, LIENS', 'Bach Francis  SIERRA, LIENS'),
#  ('Roux Nicolas Le  SIERRA, LIENS', 'Bach Francis  SIERRA, LIENS'),
#  ('Allen Genevera I.', 'Weylandt Michael'),
#  ('Mithani Murad A.', 'Veloz Tomas'),
#  ('Mithani Murad A.', 'Gabora Liane'),
#  ('Veloz Tomas', 'Gabora Liane'),
#  ('de Oliveira Washington Alves', 'Moretti Antonio Carlos'),
#  ('de Oliveira Washington Alves', 'Reis Ednei Felix'),
#  ('Moretti Antonio Carlos', 'Reis Ednei Felix'),
#  ('Ren Zhao', 'Sun Tingni'),
#  ('Ren Zhao', 'Zhang Cun-Hui'),
#  ('Ren Zhao', 'Zhou Harrison H.'),
#  ('Sun Tingni', 'Zhang Cun-Hui'),
#  ('Sun Tingni', 'Zhou Harrison H.'),
#  ('Zhang Cun-Hui', 'Zhou Harrison H.'),
#  ('Peng Xi', 'Tang Huajin'),
#  ('Peng Xi', 'Zhang Lei'),
#  ('Peng Xi', 'Yi Zhang'),
#  ('Peng Xi', 'Xiao Shijie'),
#  ('Tang Huajin', 'Zhang Lei'),
#  ('Tang Huajin', 'Yi Zhang'),
#  ('Tang Huajin', 'Xiao Shijie'),
#  ('Zhang Lei', 'Yi Zhang'),
#  ('Zhang Lei', 'Xiao Shijie'),
#  ('Yi Zhang', 'Xiao Shijie'),
#  ('Bartlett Mark', 'Cussens James'),
#  ('Gabora Liane', 'Colgan Patrick'),
#  ('Gabora Liane', 'Kitto Kirsty'),
#  ('Kindo Bereket P.', 'Wang Hao'),
#  ('Kindo Bereket P.', 'Peña Edsel A.'),
#  ('Wang Hao', 'Peña Edsel A.'),
#  ('Aravkin Aleksandr Y.', 'Burke James V.'),
#  ('Aravkin Aleksandr Y.', 'Pillonetto Gianluigi'),
#  ('Burke James V.', 'Pillonetto Gianluigi'),
#  ('Lyzinski Vince', 'Sussman Daniel'),
#  ('Lyzinski Vince', 'Tang Minh'),
#  ('Lyzinski Vince', 'Athreya Avanti'),
#  ('Lyzinski Vince', 'Priebe Carey'),
#  ('Sussman Daniel', 'Tang Minh'),
#  ('Sussman Daniel', 'Athreya Avanti'),
#  ('Sussman Daniel', 'Priebe Carey'),
#  ('Tang Minh', 'Athreya Avanti'),
#  ('Tang Minh', 'Priebe Carey'),
#  ('Athreya Avanti', 'Priebe Carey'),
#  ('Chen Yuxin', 'Chi Yuejie'),
#  ('Chen Yuxin', 'Goldsmith Andrea'),
#  ('Chi Yuejie', 'Goldsmith Andrea'),
#  ('Huang Jian', 'Jiao Yuling'),
#  ('Huang Jian', 'Jin Bangti'),
#  ('Huang Jian', 'Liu Jin'),
#  ('Huang Jian', 'Lu Xiliang'),
#  ('Huang Jian', 'Yang Can'),
#  ('Jiao Yuling', 'Jin Bangti'),
#  ('Jiao Yuling', 'Liu Jin'),
#  ('Jiao Yuling', 'Lu Xiliang'),
#  ('Jiao Yuling', 'Yang Can'),
#  ('Jin Bangti', 'Liu Jin'),
#  ('Jin Bangti', 'Lu Xiliang'),
#  ('Jin Bangti', 'Yang Can'),
#  ('Liu Jin', 'Lu Xiliang'),
#  ('Liu Jin', 'Yang Can'),
#  ('Lu Xiliang', 'Yang Can'),
#  ('Lyzinski Vince', 'Sussman Daniel L.'),
#  ('Lyzinski Vince', 'Fishkind Donniell E.'),
#  ('Lyzinski Vince', 'Pao Henry'),
#  ('Lyzinski Vince', 'Chen Li'),
#  ('Lyzinski Vince', 'Vogelstein Joshua T.'),
#  ('Lyzinski Vince', 'Park Youngser'),
#  ('Lyzinski Vince', 'Priebe Carey E.'),
#  ('Sussman Daniel L.', 'Fishkind Donniell E.'),
#  ('Sussman Daniel L.', 'Pao Henry'),
#  ('Sussman Daniel L.', 'Chen Li'),
#  ('Sussman Daniel L.', 'Vogelstein Joshua T.'),
#  ('Sussman Daniel L.', 'Park Youngser'),
#  ('Sussman Daniel L.', 'Priebe Carey E.'),
#  ('Fishkind Donniell E.', 'Pao Henry'),
#  ('Fishkind Donniell E.', 'Chen Li'),
#  ('Fishkind Donniell E.', 'Vogelstein Joshua T.'),
#  ('Fishkind Donniell E.', 'Park Youngser'),
#  ('Fishkind Donniell E.', 'Priebe Carey E.'),
#  ('Pao Henry', 'Chen Li'),
#  ('Pao Henry', 'Vogelstein Joshua T.'),
#  ('Pao Henry', 'Park Youngser'),
#  ('Pao Henry', 'Priebe Carey E.'),
#  ('Chen Li', 'Vogelstein Joshua T.'),
#  ('Chen Li', 'Park Youngser'),
#  ('Chen Li', 'Priebe Carey E.'),
#  ('Vogelstein Joshua T.', 'Park Youngser'),
#  ('Vogelstein Joshua T.', 'Priebe Carey E.'),
#  ('Park Youngser', 'Priebe Carey E.'),
#  ('Wager Stefan', 'Blocker Alexander'),
#  ('Wager Stefan', 'Cardin Niall'),
#  ('Blocker Alexander', 'Cardin Niall'),
#  ('Sarkar Purnamrita', 'Bickel Peter J.'),
#  ('Jiang Hangjin', 'Ding Yiming'),
#  ('Tyagi Hemant', 'Cevher Volkan'),
#  ('Audiffren Julien  LIF', 'Kadri Hachem  LIF'),
#  ('Yogatama Dani', 'Routledge Bryan R.'),
#  ('Yogatama Dani', 'Smith Noah A.'),
#  ('Routledge Bryan R.', 'Smith Noah A.'),
#  ('Barbu Adrian', 'She Yiyuan'),
#  ('Barbu Adrian', 'Ding Liangjing'),
#  ('Barbu Adrian', 'Gramajo Gary'),
#  ('She Yiyuan', 'Ding Liangjing'),
#  ('She Yiyuan', 'Gramajo Gary'),
#  ('Ding Liangjing', 'Gramajo Gary'),
#  ('Qiao Xingye', 'Zhang Lingsong'),
#  ('Clement Benjamin', 'Roy Didier'),
#  ('Clement Benjamin', 'Oudeyer Pierre-Yves'),
#  ('Clement Benjamin', 'Lopes Manuel'),
#  ('Roy Didier', 'Oudeyer Pierre-Yves'),
#  ('Roy Didier', 'Lopes Manuel'),
#  ('Oudeyer Pierre-Yves', 'Lopes Manuel'),
#  ('Han Fang', 'Liu Han'),
#  ('Gabora Liane', 'Saberi Maryam'),
#  ('Waegeman Willem', 'Dembczynski Krzysztof'),
#  ('Waegeman Willem', 'Jachnik Arkadiusz'),
#  ('Waegeman Willem', 'Cheng Weiwei'),
#  ('Waegeman Willem', 'Hullermeier Eyke'),
#  ('Dembczynski Krzysztof', 'Jachnik Arkadiusz'),
#  ('Dembczynski Krzysztof', 'Cheng Weiwei'),
#  ('Dembczynski Krzysztof', 'Hullermeier Eyke'),
#  ('Jachnik Arkadiusz', 'Cheng Weiwei'),
#  ('Jachnik Arkadiusz', 'Hullermeier Eyke'),
#  ('Cheng Weiwei', 'Hullermeier Eyke'),
#  ('Needell Deanna', 'Srebro Nathan'),
#  ('Needell Deanna', 'Ward Rachel'),
#  ('Srebro Nathan', 'Ward Rachel'),
#  ('Gao Chao', 'Zhou Dengyong'),
#  ('Gatterbauer Wolfgang', 'Suciu Dan'),
#  ('Guan Peng', 'Raginsky Maxim'),
#  ('Guan Peng', 'Willett Rebecca'),
#  ('Raginsky Maxim', 'Willett Rebecca'),
#  ('Gong Xiao-Feng', 'Wang Cheng-Yuan'),
#  ('Gong Xiao-Feng', 'Hao Ya-Na'),
#  ('Gong Xiao-Feng', 'Lin Qiu-Hua'),
#  ('Wang Cheng-Yuan', 'Hao Ya-Na'),
#  ('Wang Cheng-Yuan', 'Lin Qiu-Hua'),
#  ('Hao Ya-Na', 'Lin Qiu-Hua'),
#  ('Melchior Jan', 'Fischer Asja'),
#  ('Melchior Jan', 'Wiskott Laurenz'),
#  ('Fischer Asja', 'Wiskott Laurenz'),
#  ('Gruenhage Gina', 'Opper Manfred'),
#  ('Gruenhage Gina', 'Barthelme Simon'),
#  ('Opper Manfred', 'Barthelme Simon'),
#  ('Bourgain Jean', 'Dirksen Sjoerd'),
#  ('Bourgain Jean', 'Nelson Jelani'),
#  ('Dirksen Sjoerd', 'Nelson Jelani'),
#  ('Belloni Alexandre', 'Chernozhukov Victor'),
#  ('Belloni Alexandre', 'Fernández-Val Ivan'),
#  ('Belloni Alexandre', 'Hansen Christian'),
#  ('Chernozhukov Victor', 'Fernández-Val Ivan'),
#  ('Chernozhukov Victor', 'Hansen Christian'),
#  ('Fernández-Val Ivan', 'Hansen Christian'),
#  ('Mahmud M. M. Hassan', 'Hawasly Majd'),
#  ('Mahmud M. M. Hassan', 'Rosman Benjamin'),
#  ('Mahmud M. M. Hassan', 'Ramamoorthy Subramanian'),
#  ('Hawasly Majd', 'Rosman Benjamin'),
#  ('Hawasly Majd', 'Ramamoorthy Subramanian'),
#  ('Rosman Benjamin', 'Ramamoorthy Subramanian'),
#  ('Contal Emile', 'Perchet Vianney'),
#  ('Contal Emile', 'Vayatis Nicolas'),
#  ('Perchet Vianney', 'Vayatis Nicolas'),
#  ('Deshpande Yash', 'Montanari Andrea'),
#  ('Chen Li', 'Shen Cencheng'),
#  ('Chen Li', 'Vogelstein Joshua'),
#  ('Chen Li', 'Priebe Carey'),
#  ('Shen Cencheng', 'Vogelstein Joshua'),
#  ('Shen Cencheng', 'Priebe Carey'),
#  ('Vogelstein Joshua', 'Priebe Carey'),
#  ('Lee Jason D.', 'Sun Dennis L.'),
#  ('Lee Jason D.', 'Sun Yuekai'),
#  ('Lee Jason D.', 'Taylor Jonathan E.'),
#  ('Sun Dennis L.', 'Sun Yuekai'),
#  ('Sun Dennis L.', 'Taylor Jonathan E.'),
#  ('Sun Yuekai', 'Taylor Jonathan E.'),
#  ('Nowzohour Christopher', 'Bühlmann Peter'),
#  ('Tortora Cristina', 'McNicholas Paul D.'),
#  ('Tortora Cristina', 'Browne Ryan P.'),
#  ('McNicholas Paul D.', 'Browne Ryan P.'),
#  ('Scheinberg Katya', 'Tang Xiaocheng'),
#  ('Wang Jim Jing-Yan', 'Gao Xin'),
#  ('Tyagi Hemant', 'Stich Sebastian'),
#  ('Tyagi Hemant', 'Gärtner Bernd'),
#  ('Stich Sebastian', 'Gärtner Bernd'),
#  ('Gong Xiao-Feng', 'Wang Xiu-Lin'),
#  ('Gong Xiao-Feng', 'Lin Qiu-Hua'),
#  ('Wang Xiu-Lin', 'Lin Qiu-Hua'),
#  ('Konečný Jakub', 'Richtárik Peter'),
#  ('Lesnik Dmitry', 'Schaefer Tobias'),
#  ('Fishkind D. E.', 'Lyzinski V.'),
#  ('Fishkind D. E.', 'Pao H.'),
#  ('Fishkind D. E.', 'Chen L.'),
#  ('Fishkind D. E.', 'Priebe C. E.'),
#  ('Lyzinski V.', 'Pao H.'),
#  ('Lyzinski V.', 'Chen L.'),
#  ('Lyzinski V.', 'Priebe C. E.'),
#  ('Pao H.', 'Chen L.'),
#  ('Pao H.', 'Priebe C. E.'),
#  ('Chen L.', 'Priebe C. E.'),
#  ('Ma Jianzhu', 'Wang Sheng'),
#  ('Ma Jianzhu', 'Wang Zhiyong'),
#  ('Ma Jianzhu', 'Xu Jinbo'),
#  ('Wang Sheng', 'Wang Zhiyong'),
#  ('Wang Sheng', 'Xu Jinbo'),
#  ('Wang Zhiyong', 'Xu Jinbo'),
#  ('Sriperumbudur Bharath', 'Fukumizu Kenji'),
#  ('Sriperumbudur Bharath', 'Gretton Arthur'),
#  ('Sriperumbudur Bharath', 'Hyvärinen Aapo'),
#  ('Sriperumbudur Bharath', 'Kumar Revant'),
#  ('Fukumizu Kenji', 'Gretton Arthur'),
#  ('Fukumizu Kenji', 'Hyvärinen Aapo'),
#  ('Fukumizu Kenji', 'Kumar Revant'),
#  ('Gretton Arthur', 'Hyvärinen Aapo'),
#  ('Gretton Arthur', 'Kumar Revant'),
#  ('Hyvärinen Aapo', 'Kumar Revant'),
#  ('Gribonval Rémi  INRIA - IRISA',
#   'Jenatton Rodolphe  INRIA Paris -\n  Rocquencourt, CMAP'),
#  ('Gribonval Rémi  INRIA - IRISA',
#   'Bach Francis  INRIA Paris - Rocquencourt, LIENS'),
#  ('Gribonval Rémi  INRIA - IRISA', 'Kleinsteuber Martin  TUM'),
#  ('Gribonval Rémi  INRIA - IRISA', 'Seibert Matthias  TUM'),
#  ('Jenatton Rodolphe  INRIA Paris -\n  Rocquencourt, CMAP',
#   'Bach Francis  INRIA Paris - Rocquencourt, LIENS'),
#  ('Jenatton Rodolphe  INRIA Paris -\n  Rocquencourt, CMAP',
#   'Kleinsteuber Martin  TUM'),
#  ('Jenatton Rodolphe  INRIA Paris -\n  Rocquencourt, CMAP',
#   'Seibert Matthias  TUM'),
#  ('Bach Francis  INRIA Paris - Rocquencourt, LIENS',
#   'Kleinsteuber Martin  TUM'),
#  ('Bach Francis  INRIA Paris - Rocquencourt, LIENS', 'Seibert Matthias  TUM'),
#  ('Kleinsteuber Martin  TUM', 'Seibert Matthias  TUM'),
#  ('Huang Aiping', 'Zhu William'),
#  ('Huang Aiping', 'Zhu William'),
#  ('Kanagawa Motonobu', 'Nishiyama Yu'),
#  ('Kanagawa Motonobu', 'Gretton Arthur'),
#  ('Kanagawa Motonobu', 'Fukumizu Kenji'),
#  ('Nishiyama Yu', 'Gretton Arthur'),
#  ('Nishiyama Yu', 'Fukumizu Kenji'),
#  ('Gretton Arthur', 'Fukumizu Kenji'),
#  ('Connor Patrick C.', 'Trappenberg Thomas P.'),
#  ('Shinozaki Takashi', 'Naruse Yasushi'),
#  ('Goodfellow Ian J.', 'Mirza Mehdi'),
#  ('Goodfellow Ian J.', 'Xiao Da'),
#  ('Goodfellow Ian J.', 'Courville Aaron'),
#  ('Goodfellow Ian J.', 'Bengio Yoshua'),
#  ('Mirza Mehdi', 'Xiao Da'),
#  ('Mirza Mehdi', 'Courville Aaron'),
#  ('Mirza Mehdi', 'Bengio Yoshua'),
#  ('Xiao Da', 'Courville Aaron'),
#  ('Xiao Da', 'Bengio Yoshua'),
#  ('Courville Aaron', 'Bengio Yoshua'),
#  ('Aziz Haris', 'Gaspers Serge'),
#  ('Aziz Haris', 'Mackenzie Simon'),
#  ('Aziz Haris', 'Walsh Toby'),
#  ('Gaspers Serge', 'Mackenzie Simon'),
#  ('Gaspers Serge', 'Walsh Toby'),
#  ('Mackenzie Simon', 'Walsh Toby'),
#  ('Dasgupta Sourish', 'Padia Ankur'),
#  ('Dasgupta Sourish', 'Shah Kushal'),
#  ('Dasgupta Sourish', 'Majumder Prasenjit'),
#  ('Padia Ankur', 'Shah Kushal'),
#  ('Padia Ankur', 'Majumder Prasenjit'),
#  ('Shah Kushal', 'Majumder Prasenjit'),
#  ('Chen Yudong', 'Yi Xinyang'),
#  ('Chen Yudong', 'Caramanis Constantine'),
#  ('Yi Xinyang', 'Caramanis Constantine'),
#  ('Lee Nam H.', 'Tang Runze'),
#  ('Lee Nam H.', 'Priebe Carey E.'),
#  ('Lee Nam H.', 'Rosen Michael'),
#  ('Tang Runze', 'Priebe Carey E.'),
#  ('Tang Runze', 'Rosen Michael'),
#  ('Priebe Carey E.', 'Rosen Michael'),
#  ('Xing Eric P.', 'Ho Qirong'),
#  ('Xing Eric P.', 'Dai Wei'),
#  ('Xing Eric P.', 'Kim Jin Kyu'),
#  ('Xing Eric P.', 'Wei Jinliang'),
#  ('Xing Eric P.', 'Lee Seunghak'),
#  ('Xing Eric P.', 'Zheng Xun'),
#  ('Xing Eric P.', 'Xie Pengtao'),
#  ('Xing Eric P.', 'Kumar Abhimanu'),
#  ('Xing Eric P.', 'Yu Yaoliang'),
#  ('Ho Qirong', 'Dai Wei'),
#  ('Ho Qirong', 'Kim Jin Kyu'),
#  ('Ho Qirong', 'Wei Jinliang'),
#  ('Ho Qirong', 'Lee Seunghak'),
#  ('Ho Qirong', 'Zheng Xun'),
#  ('Ho Qirong', 'Xie Pengtao'),
#  ('Ho Qirong', 'Kumar Abhimanu'),
#  ('Ho Qirong', 'Yu Yaoliang'),
#  ('Dai Wei', 'Kim Jin Kyu'),
#  ('Dai Wei', 'Wei Jinliang'),
#  ('Dai Wei', 'Lee Seunghak'),
#  ('Dai Wei', 'Zheng Xun'),
#  ('Dai Wei', 'Xie Pengtao'),
#  ('Dai Wei', 'Kumar Abhimanu'),
#  ('Dai Wei', 'Yu Yaoliang'),
#  ('Kim Jin Kyu', 'Wei Jinliang'),
#  ('Kim Jin Kyu', 'Lee Seunghak'),
#  ('Kim Jin Kyu', 'Zheng Xun'),
#  ('Kim Jin Kyu', 'Xie Pengtao'),
#  ('Kim Jin Kyu', 'Kumar Abhimanu'),
#  ('Kim Jin Kyu', 'Yu Yaoliang'),
#  ('Wei Jinliang', 'Lee Seunghak'),
#  ('Wei Jinliang', 'Zheng Xun'),
#  ('Wei Jinliang', 'Xie Pengtao'),
#  ('Wei Jinliang', 'Kumar Abhimanu'),
#  ('Wei Jinliang', 'Yu Yaoliang'),
#  ('Lee Seunghak', 'Zheng Xun'),
#  ('Lee Seunghak', 'Xie Pengtao'),
#  ('Lee Seunghak', 'Kumar Abhimanu'),
#  ('Lee Seunghak', 'Yu Yaoliang'),
#  ('Zheng Xun', 'Xie Pengtao'),
#  ('Zheng Xun', 'Kumar Abhimanu'),
#  ('Zheng Xun', 'Yu Yaoliang'),
#  ('Xie Pengtao', 'Kumar Abhimanu'),
#  ('Xie Pengtao', 'Yu Yaoliang'),
#  ('Kumar Abhimanu', 'Yu Yaoliang'),
#  ('Orbanz Peter', 'Roy Daniel M.'),
#  ('Heaukulani Creighton', 'Roy Daniel M.'),
#  ('Fan Jianqing', 'Feng Yang'),
#  ('Fan Jianqing', 'Jiang Jiancheng'),
#  ('Fan Jianqing', 'Tong Xin'),
#  ('Feng Yang', 'Jiang Jiancheng'),
#  ('Feng Yang', 'Tong Xin'),
#  ('Jiang Jiancheng', 'Tong Xin'),
#  ('Aragam Bryon', 'Zhou Qing'),
#  ('Lu Zhaosong', 'Zhang Yong'),
#  ('Caron François', 'Fox Emily B.'),
#  ('Prasad H. L', 'Prashanth L. A.'),
#  ('Prasad H. L', 'Bhatnagar Shalabh'),
#  ('Prashanth L. A.', 'Bhatnagar Shalabh'),
#  ('Moalic Laurent  IRTES - SET', 'Gondran Alexandre  MAIAA'),
#  ('Zhao Peilin', 'Zhang Tong'),
#  ('Qamar Shaan', 'Guhaniyogi Rajarshi'),
#  ('Qamar Shaan', 'Dunson David B.'),
#  ('Guhaniyogi Rajarshi', 'Dunson David B.'),
#  ('Patsolic Heather', 'Adali Sancar'),
#  ('Patsolic Heather', 'Vogelstein Joshua T.'),
#  ('Patsolic Heather', 'Park Youngser'),
#  ('Patsolic Heather', 'Friebe Carey E.'),
#  ('Patsolic Heather', 'Li Gongkai'),
#  ('Patsolic Heather', 'Lyzinski Vince'),
#  ('Adali Sancar', 'Vogelstein Joshua T.'),
#  ('Adali Sancar', 'Park Youngser'),
#  ('Adali Sancar', 'Friebe Carey E.'),
#  ('Adali Sancar', 'Li Gongkai'),
#  ('Adali Sancar', 'Lyzinski Vince'),
#  ('Vogelstein Joshua T.', 'Park Youngser'),
#  ('Vogelstein Joshua T.', 'Friebe Carey E.'),
#  ('Vogelstein Joshua T.', 'Li Gongkai'),
#  ('Vogelstein Joshua T.', 'Lyzinski Vince'),
#  ('Park Youngser', 'Friebe Carey E.'),
#  ('Park Youngser', 'Li Gongkai'),
#  ('Park Youngser', 'Lyzinski Vince'),
#  ('Friebe Carey E.', 'Li Gongkai'),
#  ('Friebe Carey E.', 'Lyzinski Vince'),
#  ('Li Gongkai', 'Lyzinski Vince'),
#  ('Ames Brendan P. W.', 'Hong Mingyi'),
#  ('Solin Arno', 'Särkkä Simo'),
#  ('Ravanbakhsh Siamak', 'Greiner Russell'),
#  ('Lei Jing', 'Vu Vincent Q.'),
#  ('Byrd R. H.', 'Hansen S. L.'),
#  ('Byrd R. H.', 'Nocedal J.'),
#  ('Byrd R. H.', 'Singer Y.'),
#  ('Hansen S. L.', 'Nocedal J.'),
#  ('Hansen S. L.', 'Singer Y.'),
#  ('Nocedal J.', 'Singer Y.'),
#  ('Albrecht Stefano V.', 'Ramamoorthy Subramanian'),
#  ('Venuto David', 'Hocking Toby Dylan'),
#  ('Venuto David', 'Sphanurattana Lakjaree'),
#  ('Venuto David', 'Sugiyama Masashi'),
#  ('Hocking Toby Dylan', 'Sphanurattana Lakjaree'),
#  ('Hocking Toby Dylan', 'Sugiyama Masashi'),
#  ('Sphanurattana Lakjaree', 'Sugiyama Masashi'),
#  ('Minh Ha Quang', 'Bazzani Loris'),
#  ('Minh Ha Quang', 'Murino Vittorio'),
#  ('Bazzani Loris', 'Murino Vittorio'),
#  ('Harandi Mehrtash', 'Hartley Richard'),
#  ('Harandi Mehrtash', 'Shen Chunhua'),
#  ('Harandi Mehrtash', 'Lovell Brian'),
#  ('Harandi Mehrtash', 'Sanderson Conrad'),
#  ('Hartley Richard', 'Shen Chunhua'),
#  ('Hartley Richard', 'Lovell Brian'),
#  ('Hartley Richard', 'Sanderson Conrad'),
#  ('Shen Chunhua', 'Lovell Brian'),
#  ('Shen Chunhua', 'Sanderson Conrad'),
#  ('Lovell Brian', 'Sanderson Conrad'),
#  ('Suzuki Toshio', 'Niida Yoshinao'),
#  ('Dibbelt Julian', 'Strasser Ben'),
#  ('Dibbelt Julian', 'Wagner Dorothea'),
#  ('Strasser Ben', 'Wagner Dorothea'),
#  ('Qian Qi', 'Jin Rong'),
#  ('Qian Qi', 'Zhu Shenghuo'),
#  ('Qian Qi', 'Lin Yuanqing'),
#  ('Jin Rong', 'Zhu Shenghuo'),
#  ('Jin Rong', 'Lin Yuanqing'),
#  ('Zhu Shenghuo', 'Lin Yuanqing'),
#  ('Kingma Diederik P.', 'Welling Max'),
#  ('Osband Ian', 'Van Roy Benjamin'),
#  ('Osband Ian', 'Wen Zheng'),
#  ('Van Roy Benjamin', 'Wen Zheng'),
#  ('Perraudin Nathanael', 'Kalofolias Vassilis'),
#  ('Perraudin Nathanael', 'Shuman David'),
#  ('Perraudin Nathanael', 'Vandergheynst Pierre'),
#  ('Kalofolias Vassilis', 'Shuman David'),
#  ('Kalofolias Vassilis', 'Vandergheynst Pierre'),
#  ('Shuman David', 'Vandergheynst Pierre'),
#  ('Jampani Varun', 'Nowozin Sebastian'),
#  ('Jampani Varun', 'Loper Matthew'),
#  ('Jampani Varun', 'Gehler Peter V.'),
#  ('Nowozin Sebastian', 'Loper Matthew'),
#  ('Nowozin Sebastian', 'Gehler Peter V.'),
#  ('Loper Matthew', 'Gehler Peter V.'),
#  ('Chen Yudong', 'Xu Jiaming'),
#  ('Kabashima Yoshiyuki', 'Krzakala Florent'),
#  ('Kabashima Yoshiyuki', 'Mézard Marc'),
#  ('Kabashima Yoshiyuki', 'Sakata Ayaka'),
#  ('Kabashima Yoshiyuki', 'Zdeborová Lenka'),
#  ('Krzakala Florent', 'Mézard Marc'),
#  ('Krzakala Florent', 'Sakata Ayaka'),
#  ('Krzakala Florent', 'Zdeborová Lenka'),
#  ('Mézard Marc', 'Sakata Ayaka'),
#  ('Mézard Marc', 'Zdeborová Lenka'),
#  ('Sakata Ayaka', 'Zdeborová Lenka'),
#  ('Dalalyan Arnak S.', 'Hebiri Mohamed'),
#  ('Dalalyan Arnak S.', 'Lederer Johannes'),
#  ('Hebiri Mohamed', 'Lederer Johannes'),
#  ('Szabo Zoltan', 'Gretton Arthur'),
#  ('Szabo Zoltan', 'Poczos Barnabas'),
#  ('Szabo Zoltan', 'Sriperumbudur Bharath'),
#  ('Gretton Arthur', 'Poczos Barnabas'),
#  ('Gretton Arthur', 'Sriperumbudur Bharath'),
#  ('Poczos Barnabas', 'Sriperumbudur Bharath'),
#  ('Mannor Shie  EE-Technion', 'Perchet Vianney  GREGH'),
#  ('Mannor Shie  EE-Technion', 'Stoltz Gilles  GREGH'),
#  ('Perchet Vianney  GREGH', 'Stoltz Gilles  GREGH'),
#  ('Skowron Piotr', 'Faliszewski Piotr'),
#  ('Skowron Piotr', 'Lang Jerome'),
#  ('Faliszewski Piotr', 'Lang Jerome'),
#  ('Konda Kishore', 'Memisevic Roland'),
#  ('Konda Kishore', 'Krueger David'),
#  ('Memisevic Roland', 'Krueger David'),
#  ('Montufar Guido', 'Ay Nihat'),
#  ('Montufar Guido', 'Ghazi-Zahedi Keyan'),
#  ('Ay Nihat', 'Ghazi-Zahedi Keyan'),
#  ('Gonen Alon', 'Rosenbaum Dan'),
#  ('Gonen Alon', 'Eldar Yonina'),
#  ('Gonen Alon', 'Shalev-Shwartz Shai'),
#  ('Rosenbaum Dan', 'Eldar Yonina'),
#  ('Rosenbaum Dan', 'Shalev-Shwartz Shai'),
#  ('Eldar Yonina', 'Shalev-Shwartz Shai'),
#  ('Sedghi Hanie', 'Anandkumar Anima'),
#  ('Sedghi Hanie', 'Jonckheere Edmond'),
#  ('Anandkumar Anima', 'Jonckheere Edmond'),
#  ('Anandkumar Animashree', 'Ge Rong'),
#  ('Anandkumar Animashree', 'Janzamin Majid'),
#  ('Ge Rong', 'Janzamin Majid'),
#  ('Bertsimas Dimitris', 'Kallus Nathan'),
#  ('Saeedi Ardavan', 'Kulkarni Tejas D'),
#  ('Saeedi Ardavan', 'Mansinghka Vikash'),
#  ('Saeedi Ardavan', 'Gershman Samuel'),
#  ('Kulkarni Tejas D', 'Mansinghka Vikash'),
#  ('Kulkarni Tejas D', 'Gershman Samuel'),
#  ('Mansinghka Vikash', 'Gershman Samuel'),
#  ('Ampellio Enrico', 'Vassio Luca'),
#  ('Duvenaud David', 'Rippel Oren'),
#  ('Duvenaud David', 'Adams Ryan P.'),
#  ('Duvenaud David', 'Ghahramani Zoubin'),
#  ('Rippel Oren', 'Adams Ryan P.'),
#  ('Rippel Oren', 'Ghahramani Zoubin'),
#  ('Adams Ryan P.', 'Ghahramani Zoubin'),
#  ('Hamed Mohammad Ghasemi', 'Serrurier Mathieu'),
#  ('Hamed Mohammad Ghasemi', 'Durand Nicolas'),
#  ('Serrurier Mathieu', 'Durand Nicolas'),
#  ('Calandra Roberto', 'Peters Jan'),
#  ('Calandra Roberto', 'Rasmussen Carl Edward'),
#  ('Calandra Roberto', 'Deisenroth Marc Peter'),
#  ('Peters Jan', 'Rasmussen Carl Edward'),
#  ('Peters Jan', 'Deisenroth Marc Peter'),
#  ('Rasmussen Carl Edward', 'Deisenroth Marc Peter'),
#  ('Yu Felix X.', 'Choromanski Krzysztof'),
#  ('Yu Felix X.', 'Kumar Sanjiv'),
#  ('Yu Felix X.', 'Jebara Tony'),
#  ('Yu Felix X.', 'Chang Shih-Fu'),
#  ('Choromanski Krzysztof', 'Kumar Sanjiv'),
#  ('Choromanski Krzysztof', 'Jebara Tony'),
#  ('Choromanski Krzysztof', 'Chang Shih-Fu'),
#  ...]

# %%
weighted_author_edge_list = list(Counter(author_edge_list).items())
weighted_author_edge_list
# Out:
# [(('Montanari Andrea', 'Ricci-Tersenghi Federico'), 2),
#  (('Montanari Andrea', 'Semerjian Guilhem'), 1),
#  (('Ricci-Tersenghi Federico', 'Semerjian Guilhem'), 1),
#  (('Beygelzimer Alina', 'Langford John'), 3),
#  (('Kuznetsov Sergei O.', 'Ignatov Dmitry I.'), 1),
#  (('Blume Lawrence', 'Easley David'), 1),
#  (('Blume Lawrence', 'Halpern Joseph Y.'), 1),
#  (('Easley David', 'Halpern Joseph Y.'), 1),
#  (('Kakade Sham M.', 'Shamir Ohad'), 1),
#  (('Kakade Sham M.', 'Sridharan Karthik'), 1),
#  (('Kakade Sham M.', 'Tewari Ambuj'), 1),
#  (('Shamir Ohad', 'Sridharan Karthik'), 2),
#  (('Shamir Ohad', 'Tewari Ambuj'), 1),
#  (('Sridharan Karthik', 'Tewari Ambuj'), 1),
#  (('Lunagómez Simón', 'Mukherjee Sayan'), 1),
#  (('Lunagómez Simón', 'Wolpert Robert L.'), 1),
#  (('Lunagómez Simón', 'Airoldi Edoardo M.'), 1),
#  (('Mukherjee Sayan', 'Wolpert Robert L.'), 1),
#  (('Mukherjee Sayan', 'Airoldi Edoardo M.'), 1),
#  (('Wolpert Robert L.', 'Airoldi Edoardo M.'), 1),
#  (('DiPaola Steve', 'Gabora Liane'), 2),
#  (('Mossel Elchanan', 'Olsman Noah'), 1),
#  (('Mossel Elchanan', 'Tamuz Omer'), 1),
#  (('Olsman Noah', 'Tamuz Omer'), 1),
#  (('Golovin Daniel', 'Krause Andreas'), 1),
#  (('Ackerman Nathanael L.', 'Freer Cameron E.'), 1),
#  (('Ackerman Nathanael L.', 'Roy Daniel M.'), 1),
#  (('Freer Cameron E.', 'Roy Daniel M.'), 1),
#  (('Parthasarathy Dhruv', 'Shah Devavrat'), 1),
#  (('Parthasarathy Dhruv', 'Zaman Tauhid'), 1),
#  (('Shah Devavrat', 'Zaman Tauhid'), 1),
#  (('Koltchinskii Vladimir', 'Tsybakov Alexandre B.'), 1),
#  (('Koltchinskii Vladimir', 'Lounici Karim'), 1),
#  (('Tsybakov Alexandre B.', 'Lounici Karim'), 1),
#  (('Chen Yudong', 'Xu Huan'), 2),
#  (('Chen Yudong', 'Caramanis Constantine'), 4),
#  (('Chen Yudong', 'Sanghavi Sujay'), 2),
#  (('Xu Huan', 'Caramanis Constantine'), 1),
#  (('Xu Huan', 'Sanghavi Sujay'), 1),
#  (('Caramanis Constantine', 'Sanghavi Sujay'), 4),
#  (('Langovoy Mikhail A.', 'Wittich Olaf'), 1),
#  (('Langovoy Mikhail A.', 'Davies Patrick Laurie'), 1),
#  (('Wittich Olaf', 'Davies Patrick Laurie'), 1),
#  (('Gerchinovitz Sébastien  DMA, CLASSIC', 'Yu Jia Yuan'), 1),
#  (('Cvetkovski Andrej', 'Crovella Mark'), 1),
#  (('Baxter Jonathan', 'Bartlett Peter L.'), 1),
#  (('Baxter J.', 'Bartlett P. L.'), 1),
#  (('Baxter J.', 'Weaver L.'), 1),
#  (('Bartlett P. L.', 'Weaver L.'), 1),
#  (('McDonald Daniel J.', 'Shalizi Cosma Rohilla'), 2),
#  (('Gabora Liane', 'Ranjan Apara'), 1),
#  (('Kolchinsky Artemy', 'Rocha Luis M.'), 2),
#  (('Álvarez Mauricio A.', 'Luengo David'), 1),
#  (('Álvarez Mauricio A.', 'Lawrence Neil D.'), 3),
#  (('Luengo David', 'Lawrence Neil D.'), 1),
#  (('Lopes Miles E.', 'Jacob Laurent J.'), 1),
#  (('Lopes Miles E.', 'Wainwright Martin J.'), 1),
#  (('Jacob Laurent J.', 'Wainwright Martin J.'), 1),
#  (('Bouvrie Jake', 'Hamzi Boumediene'), 2),
#  (('Camps Rosa', 'Mora Xavier'), 1),
#  (('Camps Rosa', 'Saumell Laia'), 1),
#  (('Mora Xavier', 'Saumell Laia'), 1),
#  (('Rossi Roberto', 'Hnich Brahim'), 1),
#  (('Rossi Roberto', 'Tarim S. Armagan'), 2),
#  (('Rossi Roberto', 'Prestwich Steven'), 3),
#  (('Hnich Brahim', 'Tarim S. Armagan'), 1),
#  (('Hnich Brahim', 'Prestwich Steven'), 1),
#  (('Tarim S. Armagan', 'Prestwich Steven'), 1),
#  (('Preen Richard J.', 'Bull Larry'), 7),
#  (('Sutherland Danica J.', 'Xiong Liang'), 1),
#  (('Sutherland Danica J.', 'Póczos Barnabás'), 3),
#  (('Sutherland Danica J.', 'Schneider Jeff'), 4),
#  (('Xiong Liang', 'Póczos Barnabás'), 1),
#  (('Xiong Liang', 'Schneider Jeff'), 1),
#  (('Póczos Barnabás', 'Schneider Jeff'), 4),
#  (('Yamada Makoto', 'Jitkrittum Wittawat'), 3),
#  (('Yamada Makoto', 'Sigal Leonid'), 1),
#  (('Yamada Makoto', 'Xing Eric P.'), 1),
#  (('Yamada Makoto', 'Sugiyama Masashi'), 1),
#  (('Jitkrittum Wittawat', 'Sigal Leonid'), 1),
#  (('Jitkrittum Wittawat', 'Xing Eric P.'), 1),
#  (('Jitkrittum Wittawat', 'Sugiyama Masashi'), 1),
#  (('Sigal Leonid', 'Xing Eric P.'), 1),
#  (('Sigal Leonid', 'Sugiyama Masashi'), 1),
#  (('Xing Eric P.', 'Sugiyama Masashi'), 1),
#  (('Venkataramanan Ramji', 'Joseph Antony'), 1),
#  (('Venkataramanan Ramji', 'Tatikonda Sekhar'), 1),
#  (('Joseph Antony', 'Tatikonda Sekhar'), 1),
#  (('Schulte Phillip J.', 'Tsiatis Anastasios A.'), 1),
#  (('Schulte Phillip J.', 'Laber Eric B.'), 1),
#  (('Schulte Phillip J.', 'Davidian Marie'), 1),
#  (('Tsiatis Anastasios A.', 'Laber Eric B.'), 1),
#  (('Tsiatis Anastasios A.', 'Davidian Marie'), 1),
#  (('Laber Eric B.', 'Davidian Marie'), 1),
#  (('Ndour Cheikh', 'Diop Aliou'), 1),
#  (('Ndour Cheikh', 'Dossou-Gbété Simplice'), 1),
#  (('Diop Aliou', 'Dossou-Gbété Simplice'), 1),
#  (('Liu Weidong', 'Luo Xi'), 1),
#  (('Huszár Ferenc', 'Duvenaud David'), 1),
#  (('Quinn Christopher J.', 'Kiyavash Negar'), 1),
#  (('Quinn Christopher J.', 'Coleman Todd P.'), 1),
#  (('Kiyavash Negar', 'Coleman Todd P.'), 1),
#  (('Rohe Karl', 'Qin Tai'), 1),
#  (('Rohe Karl', 'Yu Bin'), 1),
#  (('Qin Tai', 'Yu Bin'), 1),
#  (('Liberatore Paolo', 'Schaerf Marco'), 1),
#  (('Kadri Hachem  INRIA Lille - Nord Europe',
#    'Ghavamzadeh Mohammad  INRIA\n  Lille - Nord Europe'),
#   1),
#  (('Kadri Hachem  INRIA Lille - Nord Europe',
#    'Preux Philippe  INRIA Lille - Nord Europe'),
#   1),
#  (('Ghavamzadeh Mohammad  INRIA\n  Lille - Nord Europe',
#    'Preux Philippe  INRIA Lille - Nord Europe'),
#   1),
#  (('Ozay Mete', 'Öztekin Ilke'), 1),
#  (('Ozay Mete', 'Öztekin Uygar'), 1),
#  (('Ozay Mete', 'Vural Fatos T. Yarman'), 2),
#  (('Öztekin Ilke', 'Öztekin Uygar'), 1),
#  (('Öztekin Ilke', 'Vural Fatos T. Yarman'), 1),
#  (('Öztekin Uygar', 'Vural Fatos T. Yarman'), 1),
#  (('Sodhi Balwinder', 'T. Prabhakar V'), 1),
#  (('Krueger Tammo', 'Panknin Danny'), 1),
#  (('Krueger Tammo', 'Braun Mikio'), 1),
#  (('Panknin Danny', 'Braun Mikio'), 1),
#  (('Wang Chong', 'Blei David'), 1),
#  (('Wang Chong', 'Heckerman David'), 1),
#  (('Blei David', 'Heckerman David'), 1),
#  (('Honorio Jean', 'Ortiz Luis'), 1),
#  (('Vanhatalo Jarno', 'Riihimäki Jaakko'), 1),
#  (('Vanhatalo Jarno', 'Hartikainen Jouni'), 1),
#  (('Vanhatalo Jarno', 'Jylänki Pasi'), 1),
#  (('Vanhatalo Jarno', 'Tolvanen Ville'), 1),
#  (('Vanhatalo Jarno', 'Vehtari Aki'), 1),
#  (('Riihimäki Jaakko', 'Hartikainen Jouni'), 1),
#  (('Riihimäki Jaakko', 'Jylänki Pasi'), 1),
#  (('Riihimäki Jaakko', 'Tolvanen Ville'), 1),
#  (('Riihimäki Jaakko', 'Vehtari Aki'), 1),
#  (('Hartikainen Jouni', 'Jylänki Pasi'), 1),
#  (('Hartikainen Jouni', 'Tolvanen Ville'), 1),
#  (('Hartikainen Jouni', 'Vehtari Aki'), 1),
#  (('Jylänki Pasi', 'Tolvanen Ville'), 1),
#  (('Jylänki Pasi', 'Vehtari Aki'), 1),
#  (('Tolvanen Ville', 'Vehtari Aki'), 1),
#  (('Flynn Cheryl J.', 'Perry Patrick O.'), 1),
#  (('Deisenroth Marc Peter', 'Mohamed Shakir'), 1),
#  (('Hanneke Steve', 'Yang Liu'), 3),
#  (('Honorio Jean', 'Jaakkola Tommi'), 2),
#  (('Honorio Jean', 'Samaras Dimitris'), 1),
#  (('Jaakkola Tommi', 'Samaras Dimitris'), 1),
#  (('Chadha Aman', 'Mallik Sushmit'), 1),
#  (('Chadha Aman', 'Johar Ravdeep'), 1),
#  (('Mallik Sushmit', 'Johar Ravdeep'), 1),
#  (('Fishkind Donniell E.', 'Adali Sancar'), 1),
#  (('Fishkind Donniell E.', 'Patsolic Heather G.'), 1),
#  (('Fishkind Donniell E.', 'Meng Lingyao'), 1),
#  (('Fishkind Donniell E.', 'Singh Digvijay'), 1),
#  (('Fishkind Donniell E.', 'Lyzinski Vince'), 2),
#  (('Fishkind Donniell E.', 'Priebe Carey E.'), 5),
#  (('Adali Sancar', 'Patsolic Heather G.'), 1),
#  (('Adali Sancar', 'Meng Lingyao'), 1),
#  (('Adali Sancar', 'Singh Digvijay'), 1),
#  (('Adali Sancar', 'Lyzinski Vince'), 2),
#  (('Adali Sancar', 'Priebe Carey E.'), 1),
#  (('Patsolic Heather G.', 'Meng Lingyao'), 1),
#  (('Patsolic Heather G.', 'Singh Digvijay'), 1),
#  (('Patsolic Heather G.', 'Lyzinski Vince'), 2),
#  (('Patsolic Heather G.', 'Priebe Carey E.'), 2),
#  (('Meng Lingyao', 'Singh Digvijay'), 1),
#  (('Meng Lingyao', 'Lyzinski Vince'), 1),
#  (('Meng Lingyao', 'Priebe Carey E.'), 1),
#  (('Singh Digvijay', 'Lyzinski Vince'), 1),
#  (('Singh Digvijay', 'Priebe Carey E.'), 1),
#  (('Lyzinski Vince', 'Priebe Carey E.'), 9),
#  (('Delalleau Olivier', 'Courville Aaron'), 1),
#  (('Delalleau Olivier', 'Bengio Yoshua'), 1),
#  (('Courville Aaron', 'Bengio Yoshua'), 17),
#  (('Bahmani Sohail', 'Boufounos Petros T.'), 1),
#  (('Bahmani Sohail', 'Raj Bhiksha'), 1),
#  (('Boufounos Petros T.', 'Raj Bhiksha'), 1),
#  (('Negahban Sahand', 'Oh Sewoong'), 2),
#  (('Negahban Sahand', 'Shah Devavrat'), 1),
#  (('Oh Sewoong', 'Shah Devavrat'), 1),
#  (('Grandvalet Yves', 'Chiquet Julien'), 1),
#  (('Grandvalet Yves', 'Ambroise Christophe'), 1),
#  (('Chiquet Julien', 'Ambroise Christophe'), 1),
#  (('Sanghavi Sujay', 'Xu Huan'), 1),
#  (('Miao Weimin', 'Pan Shaohua'), 1),
#  (('Miao Weimin', 'Sun Defeng'), 1),
#  (('Pan Shaohua', 'Sun Defeng'), 1),
#  (('Fan Jianqing', 'Xue Lingzhou'), 2),
#  (('Fan Jianqing', 'Zou Hui'), 1),
#  (('Xue Lingzhou', 'Zou Hui'), 2),
#  (('Beleites Claudia', 'Neugebauer Ute'), 1),
#  (('Beleites Claudia', 'Bocklitz Thomas'), 1),
#  (('Beleites Claudia', 'Krafft Christoph'), 1),
#  (('Beleites Claudia', 'Popp Jürgen'), 1),
#  (('Neugebauer Ute', 'Bocklitz Thomas'), 1),
#  (('Neugebauer Ute', 'Krafft Christoph'), 1),
#  (('Neugebauer Ute', 'Popp Jürgen'), 1),
#  (('Bocklitz Thomas', 'Krafft Christoph'), 1),
#  (('Bocklitz Thomas', 'Popp Jürgen'), 1),
#  (('Krafft Christoph', 'Popp Jürgen'), 1),
#  (('Rambhatla Sirisha', 'Haupt Jarvis D.'), 1),
#  (('McDonald Daniel J.', 'Schervish Mark'), 1),
#  (('Shalizi Cosma Rohilla', 'Schervish Mark'), 1),
#  (('Masnadi-Shirazi Hamed', 'Vasconcelos Nuno'), 1),
#  (('Masnadi-Shirazi Hamed', 'Iranmehr Arya'), 1),
#  (('Vasconcelos Nuno', 'Iranmehr Arya'), 1),
#  (('Belanich Joshua', 'Ortiz Luis E.'), 2),
#  (('Sabato Sivan', 'Shalev-Shwartz Shai'), 1),
#  (('Sabato Sivan', 'Srebro Nathan'), 1),
#  (('Sabato Sivan', 'Hsu Daniel'), 1),
#  (('Sabato Sivan', 'Zhang Tong'), 1),
#  (('Shalev-Shwartz Shai', 'Srebro Nathan'), 1),
#  (('Shalev-Shwartz Shai', 'Hsu Daniel'), 1),
#  (('Shalev-Shwartz Shai', 'Zhang Tong'), 1),
#  (('Srebro Nathan', 'Hsu Daniel'), 1),
#  (('Srebro Nathan', 'Zhang Tong'), 2),
#  (('Hsu Daniel', 'Zhang Tong'), 1),
#  (('Richtárik Peter', 'Jahani Majid'), 1),
#  (('Richtárik Peter', 'Ahipaşaoğlu Selin Damla'), 1),
#  (('Richtárik Peter', 'Takáč Martin'), 5),
#  (('Jahani Majid', 'Ahipaşaoğlu Selin Damla'), 1),
#  (('Jahani Majid', 'Takáč Martin'), 6),
#  (('Ahipaşaoğlu Selin Damla', 'Takáč Martin'), 1),
#  (('Kadie Carl', 'Meek Christopher'), 1),
#  (('Kadie Carl', 'Heckerman David'), 1),
#  (('Meek Christopher', 'Heckerman David'), 3),
#  (('Shani Guy', 'Brafman Ronen I.'), 1),
#  (('Shani Guy', 'Heckerman David'), 1),
#  (('Brafman Ronen I.', 'Heckerman David'), 1),
#  (('Wang Ziyu', 'Hutter Frank'), 1),
#  (('Wang Ziyu', 'Zoghi Masrour'), 1),
#  (('Wang Ziyu', 'Matheson David'), 1),
#  (('Wang Ziyu', 'de Freitas Nando'), 14),
#  (('Hutter Frank', 'Zoghi Masrour'), 1),
#  (('Hutter Frank', 'Matheson David'), 1),
#  (('Hutter Frank', 'de Freitas Nando'), 1),
#  (('Zoghi Masrour', 'Matheson David'), 1),
#  (('Zoghi Masrour', 'de Freitas Nando'), 1),
#  (('Matheson David', 'de Freitas Nando'), 1),
#  (('Fishkind Donniell E.', 'Shen Cencheng'), 1),
#  (('Fishkind Donniell E.', 'Park Youngser'), 3),
#  (('Shen Cencheng', 'Park Youngser'), 1),
#  (('Shen Cencheng', 'Priebe Carey E.'), 7),
#  (('Park Youngser', 'Priebe Carey E.'), 10),
#  (('Zhang Xiaowang', 'Wang Kewen'), 1),
#  (('Zhang Xiaowang', 'Wang Zhe'), 1),
#  (('Zhang Xiaowang', 'Ma Yue'), 1),
#  (('Zhang Xiaowang', 'Qi Guilin'), 1),
#  (('Wang Kewen', 'Wang Zhe'), 2),
#  (('Wang Kewen', 'Ma Yue'), 1),
#  (('Wang Kewen', 'Qi Guilin'), 1),
#  (('Wang Zhe', 'Ma Yue'), 1),
#  (('Wang Zhe', 'Qi Guilin'), 1),
#  (('Ma Yue', 'Qi Guilin'), 1),
#  (('Kearns Michael', 'Littman Michael L.'), 1),
#  (('Kearns Michael', 'Singh Satinder'), 1),
#  (('Littman Michael L.', 'Singh Satinder'), 2),
#  (('Yang Eunho', 'Ravikumar Pradeep'), 2),
#  (('Yang Eunho', 'Allen Genevera I.'), 2),
#  (('Yang Eunho', 'Liu Zhandong'), 1),
#  (('Ravikumar Pradeep', 'Allen Genevera I.'), 1),
#  (('Ravikumar Pradeep', 'Liu Zhandong'), 1),
#  (('Allen Genevera I.', 'Liu Zhandong'), 1),
#  (('Garber Dan', 'Hazan Elad'), 1),
#  (('Lin Tianyi', 'Ma Shiqian'), 3),
#  (('Lin Tianyi', 'Zhang Shuzhong'), 3),
#  (('Ma Shiqian', 'Zhang Shuzhong'), 5),
#  (('Chickering David Maxwell', 'Heckerman David'), 4),
#  (('Geiger Dan', 'Heckerman David'), 8),
#  (('Heckerman David', 'Horvitz Eric J.'), 3),
#  (('Meila Marina', 'Heckerman David'), 1),
#  (('Thiesson Bo', 'Meek Christopher'), 1),
#  (('Thiesson Bo', 'Chickering David Maxwell'), 1),
#  (('Thiesson Bo', 'Heckerman David'), 1),
#  (('Meek Christopher', 'Chickering David Maxwell'), 1),
#  (('Chickering David Maxwell', 'Meek Christopher'), 2),
#  (('Heckerman David', 'Meek Christopher'), 2),
#  (('Horvat Marko', 'Grbin Anton'), 1),
#  (('Horvat Marko', 'Gledec Gordan'), 1),
#  (('Grbin Anton', 'Gledec Gordan'), 1),
#  (('Gottlieb Lee-Ad', 'Kontorovich Aryeh'), 4),
#  (('Gottlieb Lee-Ad', 'Krauthgamer Robert'), 1),
#  (('Kontorovich Aryeh', 'Krauthgamer Robert'), 1),
#  (('Breese John S.', 'Heckerman David'), 1),
#  (('Geiger Dan', 'Meek Christopher'), 1),
#  (('Heckerman David', 'Shachter Ross D.'), 2),
#  (('Heckerman David', 'Geiger Dan'), 3),
#  (('Françoisse Kevin', 'Kivimäki Ilkka'), 1),
#  (('Françoisse Kevin', 'Mantrach Amin'), 1),
#  (('Françoisse Kevin', 'Rossi Fabrice'), 1),
#  (('Françoisse Kevin', 'Saerens Marco'), 1),
#  (('Kivimäki Ilkka', 'Mantrach Amin'), 1),
#  (('Kivimäki Ilkka', 'Rossi Fabrice'), 1),
#  (('Kivimäki Ilkka', 'Saerens Marco'), 3),
#  (('Mantrach Amin', 'Rossi Fabrice'), 1),
#  (('Mantrach Amin', 'Saerens Marco'), 1),
#  (('Rossi Fabrice', 'Saerens Marco'), 1),
#  (('Heckerman David', 'Breese John S.'), 1),
#  (('Heckerman David', 'Chickering David Maxwell'), 1),
#  (('Geiger Dan', 'Chickering David Maxwell'), 1),
#  (('Cai T. Tony', 'Zhou Wen-Xin'), 1),
#  (('Blanchard Gilles', 'Flaska Marek'), 1),
#  (('Blanchard Gilles', 'Handy Gregory'), 1),
#  (('Blanchard Gilles', 'Pozzi Sara'), 1),
#  (('Blanchard Gilles', 'Scott Clayton'), 3),
#  (('Flaska Marek', 'Handy Gregory'), 1),
#  (('Flaska Marek', 'Pozzi Sara'), 1),
#  (('Flaska Marek', 'Scott Clayton'), 1),
#  (('Handy Gregory', 'Pozzi Sara'), 1),
#  (('Handy Gregory', 'Scott Clayton'), 1),
#  (('Pozzi Sara', 'Scott Clayton'), 1),
#  (('Heckerman David', 'Shwe Michael'), 1),
#  (('Lim Chinghway', 'Yu Bin'), 1),
#  (('Baldassarre Luca', 'Bhan Nirav'), 1),
#  (('Baldassarre Luca', 'Cevher Volkan'), 4),
#  (('Baldassarre Luca', 'Kyrillidis Anastasios'), 1),
#  (('Baldassarre Luca', 'Satpathi Siddhartha'), 1),
#  (('Bhan Nirav', 'Cevher Volkan'), 1),
#  (('Bhan Nirav', 'Kyrillidis Anastasios'), 1),
#  (('Bhan Nirav', 'Satpathi Siddhartha'), 1),
#  (('Cevher Volkan', 'Kyrillidis Anastasios'), 2),
#  (('Cevher Volkan', 'Satpathi Siddhartha'), 1),
#  (('Kyrillidis Anastasios', 'Satpathi Siddhartha'), 1),
#  (('Tomal Jabed H.', 'Welch William J.'), 1),
#  (('Tomal Jabed H.', 'Zamar Ruben H.'), 1),
#  (('Welch William J.', 'Zamar Ruben H.'), 2),
#  (('Isaac Yoann', 'Barthélemy Quentin'), 1),
#  (('Isaac Yoann', 'Atif Jamal'), 1),
#  (('Isaac Yoann', 'Gouy-Pailler Cédric'), 1),
#  (('Isaac Yoann', 'Sebag Michèle'), 1),
#  (('Barthélemy Quentin', 'Atif Jamal'), 1),
#  (('Barthélemy Quentin', 'Gouy-Pailler Cédric'), 1),
#  (('Barthélemy Quentin', 'Sebag Michèle'), 1),
#  (('Atif Jamal', 'Gouy-Pailler Cédric'), 1),
#  (('Atif Jamal', 'Sebag Michèle'), 1),
#  (('Gouy-Pailler Cédric', 'Sebag Michèle'), 1),
#  (('Heckerman David', 'Middleton Blackford'), 1),
#  (('Horvitz Eric J.', 'Middleton Blackford'), 1),
#  (('Aksoylar Cem', 'Atia George'), 1),
#  (('Aksoylar Cem', 'Saligrama Venkatesh'), 2),
#  (('Atia George', 'Saligrama Venkatesh'), 1),
#  (('Karaaslan Faruk', 'Cagman Naim'), 1),
#  (('Karaaslan Faruk', 'Yilmaz Saban'), 1),
#  (('Cagman Naim', 'Yilmaz Saban'), 1),
#  (('Cheng Jie', 'Li Tianxi'), 1),
#  (('Cheng Jie', 'Levina Elizaveta'), 1),
#  (('Cheng Jie', 'Zhu Ji'), 1),
#  (('Li Tianxi', 'Levina Elizaveta'), 5),
#  (('Li Tianxi', 'Zhu Ji'), 4),
#  (('Levina Elizaveta', 'Zhu Ji'), 10),
#  (('Gaynor Sheila', 'Bair Eric'), 1),
#  (('Dasgupta Sayan', 'Goldberg Yair'), 1),
#  (('Dasgupta Sayan', 'Kosorok Michael'), 1),
#  (('Goldberg Yair', 'Kosorok Michael'), 1),
#  (('Chen Jianhui', 'Yang Tianbao'), 1),
#  (('Chen Jianhui', 'Lin Qihang'), 1),
#  (('Chen Jianhui', 'Zhang Lijun'), 1),
#  (('Chen Jianhui', 'Chang Yi'), 2),
#  (('Yang Tianbao', 'Lin Qihang'), 7),
#  (('Yang Tianbao', 'Zhang Lijun'), 7),
#  (('Yang Tianbao', 'Chang Yi'), 1),
#  (('Lin Qihang', 'Zhang Lijun'), 3),
#  (('Lin Qihang', 'Chang Yi'), 1),
#  (('Zhang Lijun', 'Chang Yi'), 1),
#  (('Zhen Liangli', 'Yi Zhang'), 1),
#  (('Zhen Liangli', 'Peng Xi'), 1),
#  (('Zhen Liangli', 'Peng Dezhong'), 2),
#  (('Yi Zhang', 'Peng Xi'), 1),
#  (('Yi Zhang', 'Peng Dezhong'), 1),
#  (('Peng Xi', 'Peng Dezhong'), 1),
#  (('Barbu Adrian', 'Wu Tianfu'), 1),
#  (('Barbu Adrian', 'Wu Ying Nian'), 1),
#  (('Wu Tianfu', 'Wu Ying Nian'), 2),
#  (('Liu Han', 'Wang Lie'), 1),
#  (('Liu Han', 'Zhao Tuo'), 6),
#  (('Wang Lie', 'Zhao Tuo'), 1),
#  (('Loh Po-Ling', 'Wainwright Martin J.'), 1),
#  (('Cseke Botond', 'Mangion Andrew Zammit'), 1),
#  (('Cseke Botond', 'Heskes Tom'), 1),
#  (('Cseke Botond', 'Sanguinetti Guido'), 3),
#  (('Mangion Andrew Zammit', 'Heskes Tom'), 1),
#  (('Mangion Andrew Zammit', 'Sanguinetti Guido'), 1),
#  (('Heskes Tom', 'Sanguinetti Guido'), 1),
#  (('Wegkamp Marten', 'Zhao Yue'), 1),
#  (('Han Fang', 'Liu Han'), 3),
#  (('Netrapalli Praneeth', 'Jain Prateek'), 2),
#  (('Netrapalli Praneeth', 'Sanghavi Sujay'), 2),
#  (('Jain Prateek', 'Sanghavi Sujay'), 2),
#  (('Wang Yuyi', 'Ramon Jan'), 2),
#  (('Wang Yuyi', 'Guo Zheng-Chu'), 2),
#  (('Ramon Jan', 'Guo Zheng-Chu'), 2),
#  (('Balcan Maria Florina', 'Ehrlich Steven'), 1),
#  (('Balcan Maria Florina', 'Liang Yingyu'), 1),
#  (('Ehrlich Steven', 'Liang Yingyu'), 1),
#  (('Nemeth Christopher', 'Fearnhead Paul'), 4),
#  (('Nemeth Christopher', 'Mihaylova Lyudmila'), 1),
#  (('Fearnhead Paul', 'Mihaylova Lyudmila'), 1),
#  (('Dimitrakakis Christos', 'Nelson Blaine'), 1),
#  (('Dimitrakakis Christos', 'Zhang and Zuhe'), 1),
#  (('Dimitrakakis Christos', 'Mitrokotsa Aikaterini'), 1),
#  (('Dimitrakakis Christos', 'Rubinstein Benjamin'), 1),
#  (('Nelson Blaine', 'Zhang and Zuhe'), 1),
#  (('Nelson Blaine', 'Mitrokotsa Aikaterini'), 1),
#  (('Nelson Blaine', 'Rubinstein Benjamin'), 1),
#  (('Zhang and Zuhe', 'Mitrokotsa Aikaterini'), 1),
#  (('Zhang and Zuhe', 'Rubinstein Benjamin'), 1),
#  (('Mitrokotsa Aikaterini', 'Rubinstein Benjamin'), 1),
#  (('Singer Amit', 'Wu Hau-tieng'), 1),
#  (('Lang Jérôme', 'Maudet Nicolas'), 1),
#  (('Lang Jérôme', 'Polukarov Maria'), 1),
#  (('Lang Jérôme', 'Cohen-Hadria Alice'), 1),
#  (('Maudet Nicolas', 'Polukarov Maria'), 1),
#  (('Maudet Nicolas', 'Cohen-Hadria Alice'), 1),
#  (('Polukarov Maria', 'Cohen-Hadria Alice'), 1),
#  (('Vepakomma Praneeth', 'Elgammal Ahmed'), 2),
#  (('Prashanth L. A.', 'Korda Nathaniel'), 1),
#  (('Prashanth L. A.', 'Munos Rémi'), 1),
#  (('Korda Nathaniel', 'Munos Rémi'), 1),
#  (('Krauthgamer Robert', 'Nadler Boaz'), 2),
#  (('Krauthgamer Robert', 'Vilenchik Dan'), 1),
#  (('Nadler Boaz', 'Vilenchik Dan'), 1),
#  (('Lyne Anne-Marie', 'Girolami Mark'), 1),
#  (('Lyne Anne-Marie', 'Atchadé Yves'), 1),
#  (('Lyne Anne-Marie', 'Strathmann Heiko'), 1),
#  (('Lyne Anne-Marie', 'Simpson Daniel'), 1),
#  (('Girolami Mark', 'Atchadé Yves'), 1),
#  (('Girolami Mark', 'Strathmann Heiko'), 1),
#  (('Girolami Mark', 'Simpson Daniel'), 1),
#  (('Atchadé Yves', 'Strathmann Heiko'), 1),
#  (('Atchadé Yves', 'Simpson Daniel'), 1),
#  (('Strathmann Heiko', 'Simpson Daniel'), 1),
#  (('Wang Zhaoran', 'Liu Han'), 11),
#  (('Wang Zhaoran', 'Zhang Tong'), 4),
#  (('Liu Han', 'Zhang Tong'), 12),
#  (('Subedi Sanjeena', 'McNicholas Paul D.'), 1),
#  (('Mallat Stéphane', 'Waldspurger Irène'), 1),
#  (('Lu Zhaosong', 'Xiao Lin'), 1),
#  (('Sykulski Adam M.', 'Olhede Sofia C.'), 3),
#  (('Sykulski Adam M.', 'Lilly Jonathan M.'), 2),
#  (('Sykulski Adam M.', 'Early Jeffrey J.'), 2),
#  (('Olhede Sofia C.', 'Lilly Jonathan M.'), 2),
#  (('Olhede Sofia C.', 'Early Jeffrey J.'), 2),
#  (('Lilly Jonathan M.', 'Early Jeffrey J.'), 2),
#  (('Lampert Thomas A.', 'Stumpf André'), 1),
#  (('Lampert Thomas A.', 'Gançarski Pierre'), 1),
#  (('Stumpf André', 'Gançarski Pierre'), 1),
#  (('Žitnik Marinka', 'Zupan Blaž'), 1),
#  (('Hsu Daniel', 'Sabato Sivan'), 1),
#  (('Vrbik Irene', 'McNicholas Paul D.'), 1),
#  (('Kanade Varun', 'Mossel Elchanan'), 1),
#  (('Wen Zheng', 'Van Roy Benjamin'), 4),
#  (('Heckel Reinhard', 'Bölcskei Helmut'), 2),
#  (('Maathuis Marloes H.', 'Colombo Diego'), 1),
#  (('Hall Eric C.', 'Willett Rebecca M.'), 2),
#  (('Reverdy Paul', 'Srivastava Vaibhav'), 2),
#  (('Reverdy Paul', 'Leonard Naomi E.'), 2),
#  (('Srivastava Vaibhav', 'Leonard Naomi E.'), 1),
#  (('Chen Mengjie', 'Gao Chao'), 1),
#  (('Chen Mengjie', 'Zhao Hongyu'), 1),
#  (('Gao Chao', 'Zhao Hongyu'), 1),
#  (('Awasthi Pranjal', 'Balcan Maria Florina'), 1),
#  (('Awasthi Pranjal', 'Long Philip M.'), 1),
#  (('Balcan Maria Florina', 'Long Philip M.'), 1),
#  (('Mukhopadhyay Subhadeep', 'Parzen Emanuel'), 1),
#  (('Homrighausen Darren', 'McDonald Daniel J.'), 3),
#  (('Tanaka Kentaro', 'Miyakawa Masami'), 1),
#  (('Shah Rajen D.', 'Meinshausen Nicolai'), 1),
#  (('Zach Christopher', 'Häne Christian'), 1),
#  (('Martino L.', 'Casarin R.'), 1),
#  (('Martino L.', 'Leisen F.'), 1),
#  (('Martino L.', 'Luengo D.'), 4),
#  (('Casarin R.', 'Leisen F.'), 1),
#  (('Casarin R.', 'Luengo D.'), 1),
#  (('Leisen F.', 'Luengo D.'), 1),
#  (('Bagnara Roberto', 'Carlier Matthieu'), 1),
#  (('Bagnara Roberto', 'Gori Roberta'), 1),
#  (('Bagnara Roberto', 'Gotlieb Arnaud'), 1),
#  (('Carlier Matthieu', 'Gori Roberta'), 1),
#  (('Carlier Matthieu', 'Gotlieb Arnaud'), 1),
#  (('Gori Roberta', 'Gotlieb Arnaud'), 1),
#  (('Borgwardt Steffen', 'Brieden Andreas'), 1),
#  (('Borgwardt Steffen', 'Gritzmann Peter'), 1),
#  (('Brieden Andreas', 'Gritzmann Peter'), 1),
#  (('Fithian William', 'Mazumder Rahul'), 1),
#  (('Benzmüller Christoph', 'Paleo Bruno Woltzenlogel'), 1),
#  (('Tekin Cem', 'van der Schaar Mihaela'), 4),
#  (('Shi Ziqiang', 'Liu Rujie'), 2),
#  (('Gabora Liane', 'DiPaola Steve'), 1),
#  (('Zhang Zhihua', 'Li Jin'), 1),
#  (('Morris Katherine', 'McNicholas Paul D.'), 2),
#  (('Huang Furong', 'Niranjan U. N.'), 1),
#  (('Huang Furong', 'Hakeem Mohammad Umar'), 1),
#  (('Huang Furong', 'Anandkumar Animashree'), 4),
#  (('Niranjan U. N.', 'Hakeem Mohammad Umar'), 1),
#  (('Niranjan U. N.', 'Anandkumar Animashree'), 1),
#  (('Hakeem Mohammad Umar', 'Anandkumar Animashree'), 1),
#  (('Dzhafarov Ehtibar N.', 'Kujala Janne V.'), 1),
#  (('Wang Yu-Xiang', 'Xu Huan'), 1),
#  (('Schmidt Mark  SIERRA, LIENS', 'Roux Nicolas Le  SIERRA, LIENS'), 1),
#  (('Schmidt Mark  SIERRA, LIENS', 'Bach Francis  SIERRA, LIENS'), 1),
#  (('Roux Nicolas Le  SIERRA, LIENS', 'Bach Francis  SIERRA, LIENS'), 1),
#  (('Allen Genevera I.', 'Weylandt Michael'), 1),
#  (('Mithani Murad A.', 'Veloz Tomas'), 1),
#  (('Mithani Murad A.', 'Gabora Liane'), 1),
#  (('Veloz Tomas', 'Gabora Liane'), 1),
#  (('de Oliveira Washington Alves', 'Moretti Antonio Carlos'), 1),
#  (('de Oliveira Washington Alves', 'Reis Ednei Felix'), 1),
#  (('Moretti Antonio Carlos', 'Reis Ednei Felix'), 1),
#  (('Ren Zhao', 'Sun Tingni'), 1),
#  (('Ren Zhao', 'Zhang Cun-Hui'), 1),
#  (('Ren Zhao', 'Zhou Harrison H.'), 1),
#  (('Sun Tingni', 'Zhang Cun-Hui'), 1),
#  (('Sun Tingni', 'Zhou Harrison H.'), 1),
#  (('Zhang Cun-Hui', 'Zhou Harrison H.'), 1),
#  (('Peng Xi', 'Tang Huajin'), 1),
#  (('Peng Xi', 'Zhang Lei'), 1),
#  (('Peng Xi', 'Yi Zhang'), 1),
#  (('Peng Xi', 'Xiao Shijie'), 1),
#  (('Tang Huajin', 'Zhang Lei'), 1),
#  (('Tang Huajin', 'Yi Zhang'), 1),
#  (('Tang Huajin', 'Xiao Shijie'), 1),
#  (('Zhang Lei', 'Yi Zhang'), 1),
#  (('Zhang Lei', 'Xiao Shijie'), 1),
#  (('Yi Zhang', 'Xiao Shijie'), 1),
#  (('Bartlett Mark', 'Cussens James'), 1),
#  (('Gabora Liane', 'Colgan Patrick'), 1),
#  (('Gabora Liane', 'Kitto Kirsty'), 1),
#  (('Kindo Bereket P.', 'Wang Hao'), 2),
#  (('Kindo Bereket P.', 'Peña Edsel A.'), 2),
#  (('Wang Hao', 'Peña Edsel A.'), 2),
#  (('Aravkin Aleksandr Y.', 'Burke James V.'), 2),
#  (('Aravkin Aleksandr Y.', 'Pillonetto Gianluigi'), 4),
#  (('Burke James V.', 'Pillonetto Gianluigi'), 2),
#  (('Lyzinski Vince', 'Sussman Daniel'), 1),
#  (('Lyzinski Vince', 'Tang Minh'), 4),
#  (('Lyzinski Vince', 'Athreya Avanti'), 3),
#  (('Lyzinski Vince', 'Priebe Carey'), 1),
#  (('Sussman Daniel', 'Tang Minh'), 1),
#  (('Sussman Daniel', 'Athreya Avanti'), 1),
#  (('Sussman Daniel', 'Priebe Carey'), 1),
#  (('Tang Minh', 'Athreya Avanti'), 4),
#  (('Tang Minh', 'Priebe Carey'), 1),
#  (('Athreya Avanti', 'Priebe Carey'), 1),
#  (('Chen Yuxin', 'Chi Yuejie'), 11),
#  (('Chen Yuxin', 'Goldsmith Andrea'), 1),
#  (('Chi Yuejie', 'Goldsmith Andrea'), 1),
#  (('Huang Jian', 'Jiao Yuling'), 9),
#  (('Huang Jian', 'Jin Bangti'), 1),
#  (('Huang Jian', 'Liu Jin'), 5),
#  (('Huang Jian', 'Lu Xiliang'), 4),
#  (('Huang Jian', 'Yang Can'), 1),
#  (('Jiao Yuling', 'Jin Bangti'), 1),
#  (('Jiao Yuling', 'Liu Jin'), 6),
#  (('Jiao Yuling', 'Lu Xiliang'), 7),
#  (('Jiao Yuling', 'Yang Can'), 3),
#  (('Jin Bangti', 'Liu Jin'), 1),
#  (('Jin Bangti', 'Lu Xiliang'), 1),
#  (('Jin Bangti', 'Yang Can'), 1),
#  (('Liu Jin', 'Lu Xiliang'), 3),
#  (('Liu Jin', 'Yang Can'), 2),
#  (('Lu Xiliang', 'Yang Can'), 1),
#  (('Lyzinski Vince', 'Sussman Daniel L.'), 2),
#  (('Lyzinski Vince', 'Fishkind Donniell E.'), 2),
#  (('Lyzinski Vince', 'Pao Henry'), 1),
#  (('Lyzinski Vince', 'Chen Li'), 1),
#  (('Lyzinski Vince', 'Vogelstein Joshua T.'), 4),
#  (('Lyzinski Vince', 'Park Youngser'), 4),
#  (('Sussman Daniel L.', 'Fishkind Donniell E.'), 1),
#  (('Sussman Daniel L.', 'Pao Henry'), 1),
#  (('Sussman Daniel L.', 'Chen Li'), 1),
#  (('Sussman Daniel L.', 'Vogelstein Joshua T.'), 2),
#  (('Sussman Daniel L.', 'Park Youngser'), 2),
#  (('Sussman Daniel L.', 'Priebe Carey E.'), 5),
#  (('Fishkind Donniell E.', 'Pao Henry'), 1),
#  (('Fishkind Donniell E.', 'Chen Li'), 1),
#  (('Fishkind Donniell E.', 'Vogelstein Joshua T.'), 2),
#  (('Pao Henry', 'Chen Li'), 1),
#  (('Pao Henry', 'Vogelstein Joshua T.'), 1),
#  (('Pao Henry', 'Park Youngser'), 1),
#  (('Pao Henry', 'Priebe Carey E.'), 1),
#  (('Chen Li', 'Vogelstein Joshua T.'), 1),
#  (('Chen Li', 'Park Youngser'), 1),
#  (('Chen Li', 'Priebe Carey E.'), 2),
#  (('Vogelstein Joshua T.', 'Park Youngser'), 2),
#  (('Vogelstein Joshua T.', 'Priebe Carey E.'), 11),
#  (('Wager Stefan', 'Blocker Alexander'), 1),
#  (('Wager Stefan', 'Cardin Niall'), 1),
#  (('Blocker Alexander', 'Cardin Niall'), 1),
#  (('Sarkar Purnamrita', 'Bickel Peter J.'), 3),
#  (('Jiang Hangjin', 'Ding Yiming'), 2),
#  (('Tyagi Hemant', 'Cevher Volkan'), 1),
#  (('Audiffren Julien  LIF', 'Kadri Hachem  LIF'), 1),
#  (('Yogatama Dani', 'Routledge Bryan R.'), 1),
#  (('Yogatama Dani', 'Smith Noah A.'), 2),
#  (('Routledge Bryan R.', 'Smith Noah A.'), 1),
#  (('Barbu Adrian', 'She Yiyuan'), 1),
#  (('Barbu Adrian', 'Ding Liangjing'), 1),
#  (('Barbu Adrian', 'Gramajo Gary'), 1),
#  (('She Yiyuan', 'Ding Liangjing'), 1),
#  (('She Yiyuan', 'Gramajo Gary'), 1),
#  (('Ding Liangjing', 'Gramajo Gary'), 1),
#  (('Qiao Xingye', 'Zhang Lingsong'), 1),
#  (('Clement Benjamin', 'Roy Didier'), 1),
#  (('Clement Benjamin', 'Oudeyer Pierre-Yves'), 1),
#  (('Clement Benjamin', 'Lopes Manuel'), 1),
#  (('Roy Didier', 'Oudeyer Pierre-Yves'), 1),
#  (('Roy Didier', 'Lopes Manuel'), 1),
#  (('Oudeyer Pierre-Yves', 'Lopes Manuel'), 1),
#  (('Gabora Liane', 'Saberi Maryam'), 1),
#  (('Waegeman Willem', 'Dembczynski Krzysztof'), 2),
#  (('Waegeman Willem', 'Jachnik Arkadiusz'), 1),
#  (('Waegeman Willem', 'Cheng Weiwei'), 1),
#  (('Waegeman Willem', 'Hullermeier Eyke'), 1),
#  (('Dembczynski Krzysztof', 'Jachnik Arkadiusz'), 1),
#  (('Dembczynski Krzysztof', 'Cheng Weiwei'), 1),
#  (('Dembczynski Krzysztof', 'Hullermeier Eyke'), 1),
#  (('Jachnik Arkadiusz', 'Cheng Weiwei'), 1),
#  (('Jachnik Arkadiusz', 'Hullermeier Eyke'), 1),
#  (('Cheng Weiwei', 'Hullermeier Eyke'), 1),
#  (('Needell Deanna', 'Srebro Nathan'), 1),
#  (('Needell Deanna', 'Ward Rachel'), 2),
#  (('Srebro Nathan', 'Ward Rachel'), 1),
#  (('Gao Chao', 'Zhou Dengyong'), 2),
#  (('Gatterbauer Wolfgang', 'Suciu Dan'), 1),
#  (('Guan Peng', 'Raginsky Maxim'), 1),
#  (('Guan Peng', 'Willett Rebecca'), 1),
#  (('Raginsky Maxim', 'Willett Rebecca'), 1),
#  (('Gong Xiao-Feng', 'Wang Cheng-Yuan'), 1),
#  (('Gong Xiao-Feng', 'Hao Ya-Na'), 1),
#  (('Gong Xiao-Feng', 'Lin Qiu-Hua'), 3),
#  (('Wang Cheng-Yuan', 'Hao Ya-Na'), 1),
#  (('Wang Cheng-Yuan', 'Lin Qiu-Hua'), 1),
#  (('Hao Ya-Na', 'Lin Qiu-Hua'), 1),
#  (('Melchior Jan', 'Fischer Asja'), 1),
#  (('Melchior Jan', 'Wiskott Laurenz'), 2),
#  (('Fischer Asja', 'Wiskott Laurenz'), 1),
#  (('Gruenhage Gina', 'Opper Manfred'), 1),
#  (('Gruenhage Gina', 'Barthelme Simon'), 1),
#  (('Opper Manfred', 'Barthelme Simon'), 1),
#  (('Bourgain Jean', 'Dirksen Sjoerd'), 1),
#  (('Bourgain Jean', 'Nelson Jelani'), 1),
#  (('Dirksen Sjoerd', 'Nelson Jelani'), 1),
#  (('Belloni Alexandre', 'Chernozhukov Victor'), 1),
#  (('Belloni Alexandre', 'Fernández-Val Ivan'), 1),
#  (('Belloni Alexandre', 'Hansen Christian'), 1),
#  (('Chernozhukov Victor', 'Fernández-Val Ivan'), 1),
#  (('Chernozhukov Victor', 'Hansen Christian'), 3),
#  (('Fernández-Val Ivan', 'Hansen Christian'), 1),
#  (('Mahmud M. M. Hassan', 'Hawasly Majd'), 1),
#  (('Mahmud M. M. Hassan', 'Rosman Benjamin'), 1),
#  (('Mahmud M. M. Hassan', 'Ramamoorthy Subramanian'), 1),
#  (('Hawasly Majd', 'Rosman Benjamin'), 1),
#  (('Hawasly Majd', 'Ramamoorthy Subramanian'), 3),
#  (('Rosman Benjamin', 'Ramamoorthy Subramanian'), 2),
#  (('Contal Emile', 'Perchet Vianney'), 1),
#  (('Contal Emile', 'Vayatis Nicolas'), 3),
#  (('Perchet Vianney', 'Vayatis Nicolas'), 1),
#  (('Deshpande Yash', 'Montanari Andrea'), 4),
#  (('Chen Li', 'Shen Cencheng'), 1),
#  (('Chen Li', 'Vogelstein Joshua'), 1),
#  (('Chen Li', 'Priebe Carey'), 3),
#  (('Shen Cencheng', 'Vogelstein Joshua'), 1),
#  (('Shen Cencheng', 'Priebe Carey'), 2),
#  (('Vogelstein Joshua', 'Priebe Carey'), 2),
#  (('Lee Jason D.', 'Sun Dennis L.'), 1),
#  (('Lee Jason D.', 'Sun Yuekai'), 3),
#  (('Lee Jason D.', 'Taylor Jonathan E.'), 2),
#  (('Sun Dennis L.', 'Sun Yuekai'), 1),
#  (('Sun Dennis L.', 'Taylor Jonathan E.'), 1),
#  (('Sun Yuekai', 'Taylor Jonathan E.'), 2),
#  (('Nowzohour Christopher', 'Bühlmann Peter'), 2),
#  (('Tortora Cristina', 'McNicholas Paul D.'), 1),
#  (('Tortora Cristina', 'Browne Ryan P.'), 1),
#  (('McNicholas Paul D.', 'Browne Ryan P.'), 3),
#  (('Scheinberg Katya', 'Tang Xiaocheng'), 1),
#  (('Wang Jim Jing-Yan', 'Gao Xin'), 2),
#  (('Tyagi Hemant', 'Stich Sebastian'), 1),
#  (('Tyagi Hemant', 'Gärtner Bernd'), 3),
#  (('Stich Sebastian', 'Gärtner Bernd'), 1),
#  (('Gong Xiao-Feng', 'Wang Xiu-Lin'), 1),
#  (('Wang Xiu-Lin', 'Lin Qiu-Hua'), 1),
#  (('Konečný Jakub', 'Richtárik Peter'), 4),
#  (('Lesnik Dmitry', 'Schaefer Tobias'), 1),
#  (('Fishkind D. E.', 'Lyzinski V.'), 1),
#  (('Fishkind D. E.', 'Pao H.'), 1),
#  (('Fishkind D. E.', 'Chen L.'), 1),
#  (('Fishkind D. E.', 'Priebe C. E.'), 1),
#  (('Lyzinski V.', 'Pao H.'), 1),
#  (('Lyzinski V.', 'Chen L.'), 1),
#  (('Lyzinski V.', 'Priebe C. E.'), 1),
#  (('Pao H.', 'Chen L.'), 1),
#  (('Pao H.', 'Priebe C. E.'), 1),
#  (('Chen L.', 'Priebe C. E.'), 1),
#  (('Ma Jianzhu', 'Wang Sheng'), 1),
#  (('Ma Jianzhu', 'Wang Zhiyong'), 1),
#  (('Ma Jianzhu', 'Xu Jinbo'), 1),
#  (('Wang Sheng', 'Wang Zhiyong'), 1),
#  (('Wang Sheng', 'Xu Jinbo'), 3),
#  (('Wang Zhiyong', 'Xu Jinbo'), 1),
#  (('Sriperumbudur Bharath', 'Fukumizu Kenji'), 2),
#  (('Sriperumbudur Bharath', 'Gretton Arthur'), 3),
#  (('Sriperumbudur Bharath', 'Hyvärinen Aapo'), 1),
#  (('Sriperumbudur Bharath', 'Kumar Revant'), 1),
#  (('Fukumizu Kenji', 'Gretton Arthur'), 4),
#  (('Fukumizu Kenji', 'Hyvärinen Aapo'), 1),
#  (('Fukumizu Kenji', 'Kumar Revant'), 1),
#  (('Gretton Arthur', 'Hyvärinen Aapo'), 1),
#  (('Gretton Arthur', 'Kumar Revant'), 1),
#  (('Hyvärinen Aapo', 'Kumar Revant'), 1),
#  (('Gribonval Rémi  INRIA - IRISA',
#    'Jenatton Rodolphe  INRIA Paris -\n  Rocquencourt, CMAP'),
#   1),
#  (('Gribonval Rémi  INRIA - IRISA',
#    'Bach Francis  INRIA Paris - Rocquencourt, LIENS'),
#   1),
#  (('Gribonval Rémi  INRIA - IRISA', 'Kleinsteuber Martin  TUM'), 1),
#  (('Gribonval Rémi  INRIA - IRISA', 'Seibert Matthias  TUM'), 1),
#  (('Jenatton Rodolphe  INRIA Paris -\n  Rocquencourt, CMAP',
#    'Bach Francis  INRIA Paris - Rocquencourt, LIENS'),
#   1),
#  (('Jenatton Rodolphe  INRIA Paris -\n  Rocquencourt, CMAP',
#    'Kleinsteuber Martin  TUM'),
#   1),
#  (('Jenatton Rodolphe  INRIA Paris -\n  Rocquencourt, CMAP',
#    'Seibert Matthias  TUM'),
#   1),
#  (('Bach Francis  INRIA Paris - Rocquencourt, LIENS',
#    'Kleinsteuber Martin  TUM'),
#   1),
#  (('Bach Francis  INRIA Paris - Rocquencourt, LIENS', 'Seibert Matthias  TUM'),
#   1),
#  (('Kleinsteuber Martin  TUM', 'Seibert Matthias  TUM'), 1),
#  (('Huang Aiping', 'Zhu William'), 2),
#  (('Kanagawa Motonobu', 'Nishiyama Yu'), 1),
#  (('Kanagawa Motonobu', 'Gretton Arthur'), 2),
#  (('Kanagawa Motonobu', 'Fukumizu Kenji'), 5),
#  (('Nishiyama Yu', 'Gretton Arthur'), 2),
#  (('Nishiyama Yu', 'Fukumizu Kenji'), 3),
#  (('Gretton Arthur', 'Fukumizu Kenji'), 2),
#  (('Connor Patrick C.', 'Trappenberg Thomas P.'), 1),
#  (('Shinozaki Takashi', 'Naruse Yasushi'), 1),
#  (('Goodfellow Ian J.', 'Mirza Mehdi'), 1),
#  (('Goodfellow Ian J.', 'Xiao Da'), 1),
#  (('Goodfellow Ian J.', 'Courville Aaron'), 1),
#  (('Goodfellow Ian J.', 'Bengio Yoshua'), 1),
#  (('Mirza Mehdi', 'Xiao Da'), 1),
#  (('Mirza Mehdi', 'Courville Aaron'), 2),
#  (('Mirza Mehdi', 'Bengio Yoshua'), 2),
#  (('Xiao Da', 'Courville Aaron'), 1),
#  (('Xiao Da', 'Bengio Yoshua'), 1),
#  (('Aziz Haris', 'Gaspers Serge'), 4),
#  (('Aziz Haris', 'Mackenzie Simon'), 2),
#  (('Aziz Haris', 'Walsh Toby'), 8),
#  (('Gaspers Serge', 'Mackenzie Simon'), 1),
#  (('Gaspers Serge', 'Walsh Toby'), 4),
#  (('Mackenzie Simon', 'Walsh Toby'), 1),
#  (('Dasgupta Sourish', 'Padia Ankur'), 2),
#  (('Dasgupta Sourish', 'Shah Kushal'), 1),
#  (('Dasgupta Sourish', 'Majumder Prasenjit'), 1),
#  (('Padia Ankur', 'Shah Kushal'), 1),
#  (('Padia Ankur', 'Majumder Prasenjit'), 1),
#  (('Shah Kushal', 'Majumder Prasenjit'), 1),
#  (('Chen Yudong', 'Yi Xinyang'), 1),
#  (('Yi Xinyang', 'Caramanis Constantine'), 6),
#  (('Lee Nam H.', 'Tang Runze'), 1),
#  (('Lee Nam H.', 'Priebe Carey E.'), 1),
#  (('Lee Nam H.', 'Rosen Michael'), 2),
#  (('Tang Runze', 'Priebe Carey E.'), 3),
#  (('Tang Runze', 'Rosen Michael'), 1),
#  (('Priebe Carey E.', 'Rosen Michael'), 1),
#  (('Xing Eric P.', 'Ho Qirong'), 2),
#  (('Xing Eric P.', 'Dai Wei'), 2),
#  (('Xing Eric P.', 'Kim Jin Kyu'), 1),
#  (('Xing Eric P.', 'Wei Jinliang'), 1),
#  (('Xing Eric P.', 'Lee Seunghak'), 1),
#  (('Xing Eric P.', 'Zheng Xun'), 1),
#  (('Xing Eric P.', 'Xie Pengtao'), 2),
#  (('Xing Eric P.', 'Kumar Abhimanu'), 1),
#  (('Xing Eric P.', 'Yu Yaoliang'), 1),
#  (('Ho Qirong', 'Dai Wei'), 2),
#  (('Ho Qirong', 'Kim Jin Kyu'), 1),
#  (('Ho Qirong', 'Wei Jinliang'), 2),
#  (('Ho Qirong', 'Lee Seunghak'), 1),
#  (('Ho Qirong', 'Zheng Xun'), 1),
#  (('Ho Qirong', 'Xie Pengtao'), 3),
#  (('Ho Qirong', 'Kumar Abhimanu'), 1),
#  (('Ho Qirong', 'Yu Yaoliang'), 1),
#  (('Dai Wei', 'Kim Jin Kyu'), 1),
#  (('Dai Wei', 'Wei Jinliang'), 2),
#  (('Dai Wei', 'Lee Seunghak'), 1),
#  (('Dai Wei', 'Zheng Xun'), 1),
#  (('Dai Wei', 'Xie Pengtao'), 2),
#  (('Dai Wei', 'Kumar Abhimanu'), 1),
#  (('Dai Wei', 'Yu Yaoliang'), 1),
#  (('Kim Jin Kyu', 'Wei Jinliang'), 1),
#  (('Kim Jin Kyu', 'Lee Seunghak'), 1),
#  (('Kim Jin Kyu', 'Zheng Xun'), 1),
#  (('Kim Jin Kyu', 'Xie Pengtao'), 1),
#  (('Kim Jin Kyu', 'Kumar Abhimanu'), 1),
#  (('Kim Jin Kyu', 'Yu Yaoliang'), 1),
#  (('Wei Jinliang', 'Lee Seunghak'), 1),
#  (('Wei Jinliang', 'Zheng Xun'), 1),
#  (('Wei Jinliang', 'Xie Pengtao'), 2),
#  (('Wei Jinliang', 'Kumar Abhimanu'), 1),
#  (('Wei Jinliang', 'Yu Yaoliang'), 1),
#  (('Lee Seunghak', 'Zheng Xun'), 1),
#  (('Lee Seunghak', 'Xie Pengtao'), 1),
#  (('Lee Seunghak', 'Kumar Abhimanu'), 1),
#  (('Lee Seunghak', 'Yu Yaoliang'), 1),
#  (('Zheng Xun', 'Xie Pengtao'), 1),
#  (('Zheng Xun', 'Kumar Abhimanu'), 1),
#  (('Zheng Xun', 'Yu Yaoliang'), 1),
#  (('Xie Pengtao', 'Kumar Abhimanu'), 1),
#  (('Xie Pengtao', 'Yu Yaoliang'), 1),
#  (('Kumar Abhimanu', 'Yu Yaoliang'), 1),
#  (('Orbanz Peter', 'Roy Daniel M.'), 1),
#  (('Heaukulani Creighton', 'Roy Daniel M.'), 3),
#  (('Fan Jianqing', 'Feng Yang'), 2),
#  (('Fan Jianqing', 'Jiang Jiancheng'), 1),
#  (('Fan Jianqing', 'Tong Xin'), 1),
#  (('Feng Yang', 'Jiang Jiancheng'), 1),
#  (('Feng Yang', 'Tong Xin'), 3),
#  (('Jiang Jiancheng', 'Tong Xin'), 1),
#  (('Aragam Bryon', 'Zhou Qing'), 5),
#  (('Lu Zhaosong', 'Zhang Yong'), 1),
#  (('Caron François', 'Fox Emily B.'), 1),
#  (('Prasad H. L', 'Prashanth L. A.'), 1),
#  (('Prasad H. L', 'Bhatnagar Shalabh'), 1),
#  (('Prashanth L. A.', 'Bhatnagar Shalabh'), 1),
#  (('Moalic Laurent  IRTES - SET', 'Gondran Alexandre  MAIAA'), 1),
#  (('Zhao Peilin', 'Zhang Tong'), 1),
#  (('Qamar Shaan', 'Guhaniyogi Rajarshi'), 1),
#  (('Qamar Shaan', 'Dunson David B.'), 1),
#  (('Guhaniyogi Rajarshi', 'Dunson David B.'), 1),
#  (('Patsolic Heather', 'Adali Sancar'), 1),
#  (('Patsolic Heather', 'Vogelstein Joshua T.'), 1),
#  (('Patsolic Heather', 'Park Youngser'), 1),
#  (('Patsolic Heather', 'Friebe Carey E.'), 1),
#  (('Patsolic Heather', 'Li Gongkai'), 1),
#  (('Patsolic Heather', 'Lyzinski Vince'), 1),
#  (('Adali Sancar', 'Vogelstein Joshua T.'), 1),
#  (('Adali Sancar', 'Park Youngser'), 1),
#  (('Adali Sancar', 'Friebe Carey E.'), 1),
#  (('Adali Sancar', 'Li Gongkai'), 1),
#  (('Vogelstein Joshua T.', 'Friebe Carey E.'), 1),
#  (('Vogelstein Joshua T.', 'Li Gongkai'), 1),
#  (('Vogelstein Joshua T.', 'Lyzinski Vince'), 2),
#  (('Park Youngser', 'Friebe Carey E.'), 1),
#  (('Park Youngser', 'Li Gongkai'), 1),
#  (('Park Youngser', 'Lyzinski Vince'), 6),
#  (('Friebe Carey E.', 'Li Gongkai'), 1),
#  (('Friebe Carey E.', 'Lyzinski Vince'), 1),
#  (('Li Gongkai', 'Lyzinski Vince'), 1),
#  (('Ames Brendan P. W.', 'Hong Mingyi'), 1),
#  (('Solin Arno', 'Särkkä Simo'), 4),
#  (('Ravanbakhsh Siamak', 'Greiner Russell'), 4),
#  (('Lei Jing', 'Vu Vincent Q.'), 1),
#  (('Byrd R. H.', 'Hansen S. L.'), 1),
#  (('Byrd R. H.', 'Nocedal J.'), 1),
#  (('Byrd R. H.', 'Singer Y.'), 1),
#  (('Hansen S. L.', 'Nocedal J.'), 1),
#  (('Hansen S. L.', 'Singer Y.'), 1),
#  (('Nocedal J.', 'Singer Y.'), 1),
#  (('Albrecht Stefano V.', 'Ramamoorthy Subramanian'), 8),
#  (('Venuto David', 'Hocking Toby Dylan'), 1),
#  (('Venuto David', 'Sphanurattana Lakjaree'), 1),
#  (('Venuto David', 'Sugiyama Masashi'), 1),
#  (('Hocking Toby Dylan', 'Sphanurattana Lakjaree'), 1),
#  (('Hocking Toby Dylan', 'Sugiyama Masashi'), 1),
#  (('Sphanurattana Lakjaree', 'Sugiyama Masashi'), 1),
#  (('Minh Ha Quang', 'Bazzani Loris'), 1),
#  (('Minh Ha Quang', 'Murino Vittorio'), 1),
#  (('Bazzani Loris', 'Murino Vittorio'), 1),
#  (('Harandi Mehrtash', 'Hartley Richard'), 2),
#  (('Harandi Mehrtash', 'Shen Chunhua'), 1),
#  (('Harandi Mehrtash', 'Lovell Brian'), 1),
#  (('Harandi Mehrtash', 'Sanderson Conrad'), 1),
#  (('Hartley Richard', 'Shen Chunhua'), 1),
#  (('Hartley Richard', 'Lovell Brian'), 1),
#  (('Hartley Richard', 'Sanderson Conrad'), 1),
#  (('Shen Chunhua', 'Lovell Brian'), 1),
#  (('Shen Chunhua', 'Sanderson Conrad'), 1),
#  (('Lovell Brian', 'Sanderson Conrad'), 1),
#  (('Suzuki Toshio', 'Niida Yoshinao'), 1),
#  (('Dibbelt Julian', 'Strasser Ben'), 1),
#  (('Dibbelt Julian', 'Wagner Dorothea'), 1),
#  (('Strasser Ben', 'Wagner Dorothea'), 1),
#  (('Qian Qi', 'Jin Rong'), 9),
#  (('Qian Qi', 'Zhu Shenghuo'), 5),
#  (('Qian Qi', 'Lin Yuanqing'), 1),
#  (('Jin Rong', 'Zhu Shenghuo'), 4),
#  (('Jin Rong', 'Lin Yuanqing'), 1),
#  (('Zhu Shenghuo', 'Lin Yuanqing'), 1),
#  (('Kingma Diederik P.', 'Welling Max'), 5),
#  (('Osband Ian', 'Van Roy Benjamin'), 15),
#  (('Osband Ian', 'Wen Zheng'), 7),
#  (('Van Roy Benjamin', 'Wen Zheng'), 4),
#  (('Perraudin Nathanael', 'Kalofolias Vassilis'), 1),
#  (('Perraudin Nathanael', 'Shuman David'), 2),
#  (('Perraudin Nathanael', 'Vandergheynst Pierre'), 3),
#  (('Kalofolias Vassilis', 'Shuman David'), 1),
#  (('Kalofolias Vassilis', 'Vandergheynst Pierre'), 2),
#  (('Shuman David', 'Vandergheynst Pierre'), 2),
#  (('Jampani Varun', 'Nowozin Sebastian'), 1),
#  (('Jampani Varun', 'Loper Matthew'), 1),
#  (('Jampani Varun', 'Gehler Peter V.'), 1),
#  (('Nowozin Sebastian', 'Loper Matthew'), 1),
#  (('Nowozin Sebastian', 'Gehler Peter V.'), 1),
#  (('Loper Matthew', 'Gehler Peter V.'), 1),
#  (('Chen Yudong', 'Xu Jiaming'), 4),
#  (('Kabashima Yoshiyuki', 'Krzakala Florent'), 1),
#  (('Kabashima Yoshiyuki', 'Mézard Marc'), 1),
#  (('Kabashima Yoshiyuki', 'Sakata Ayaka'), 1),
#  (('Kabashima Yoshiyuki', 'Zdeborová Lenka'), 1),
#  (('Krzakala Florent', 'Mézard Marc'), 6),
#  (('Krzakala Florent', 'Sakata Ayaka'), 1),
#  (('Krzakala Florent', 'Zdeborová Lenka'), 35),
#  (('Mézard Marc', 'Sakata Ayaka'), 1),
#  (('Mézard Marc', 'Zdeborová Lenka'), 7),
#  (('Sakata Ayaka', 'Zdeborová Lenka'), 1),
#  (('Dalalyan Arnak S.', 'Hebiri Mohamed'), 1),
#  (('Dalalyan Arnak S.', 'Lederer Johannes'), 1),
#  (('Hebiri Mohamed', 'Lederer Johannes'), 2),
#  (('Szabo Zoltan', 'Gretton Arthur'), 6),
#  (('Szabo Zoltan', 'Poczos Barnabas'), 2),
#  (('Szabo Zoltan', 'Sriperumbudur Bharath'), 2),
#  (('Gretton Arthur', 'Poczos Barnabas'), 1),
#  (('Gretton Arthur', 'Sriperumbudur Bharath'), 1),
#  (('Poczos Barnabas', 'Sriperumbudur Bharath'), 1),
#  (('Mannor Shie  EE-Technion', 'Perchet Vianney  GREGH'), 1),
#  (('Mannor Shie  EE-Technion', 'Stoltz Gilles  GREGH'), 1),
#  (('Perchet Vianney  GREGH', 'Stoltz Gilles  GREGH'), 1),
#  (('Skowron Piotr', 'Faliszewski Piotr'), 1),
#  (('Skowron Piotr', 'Lang Jerome'), 1),
#  (('Faliszewski Piotr', 'Lang Jerome'), 1),
#  (('Konda Kishore', 'Memisevic Roland'), 2),
#  (('Konda Kishore', 'Krueger David'), 1),
#  (('Memisevic Roland', 'Krueger David'), 1),
#  (('Montufar Guido', 'Ay Nihat'), 4),
#  (('Montufar Guido', 'Ghazi-Zahedi Keyan'), 3),
#  (('Ay Nihat', 'Ghazi-Zahedi Keyan'), 1),
#  (('Gonen Alon', 'Rosenbaum Dan'), 1),
#  (('Gonen Alon', 'Eldar Yonina'), 1),
#  (('Gonen Alon', 'Shalev-Shwartz Shai'), 1),
#  (('Rosenbaum Dan', 'Eldar Yonina'), 1),
#  (('Rosenbaum Dan', 'Shalev-Shwartz Shai'), 1),
#  (('Eldar Yonina', 'Shalev-Shwartz Shai'), 1),
#  (('Sedghi Hanie', 'Anandkumar Anima'), 6),
#  (('Sedghi Hanie', 'Jonckheere Edmond'), 1),
#  (('Anandkumar Anima', 'Jonckheere Edmond'), 1),
#  (('Anandkumar Animashree', 'Ge Rong'), 1),
#  (('Anandkumar Animashree', 'Janzamin Majid'), 1),
#  (('Ge Rong', 'Janzamin Majid'), 2),
#  (('Bertsimas Dimitris', 'Kallus Nathan'), 1),
#  (('Saeedi Ardavan', 'Kulkarni Tejas D'), 1),
#  (('Saeedi Ardavan', 'Mansinghka Vikash'), 2),
#  (('Saeedi Ardavan', 'Gershman Samuel'), 1),
#  (('Kulkarni Tejas D', 'Mansinghka Vikash'), 1),
#  (('Kulkarni Tejas D', 'Gershman Samuel'), 1),
#  (('Mansinghka Vikash', 'Gershman Samuel'), 1),
#  (('Ampellio Enrico', 'Vassio Luca'), 1),
#  (('Duvenaud David', 'Rippel Oren'), 1),
#  (('Duvenaud David', 'Adams Ryan P.'), 6),
#  (('Duvenaud David', 'Ghahramani Zoubin'), 1),
#  (('Rippel Oren', 'Adams Ryan P.'), 3),
#  (('Rippel Oren', 'Ghahramani Zoubin'), 1),
#  (('Adams Ryan P.', 'Ghahramani Zoubin'), 3),
#  (('Hamed Mohammad Ghasemi', 'Serrurier Mathieu'), 1),
#  (('Hamed Mohammad Ghasemi', 'Durand Nicolas'), 1),
#  (('Serrurier Mathieu', 'Durand Nicolas'), 1),
#  (('Calandra Roberto', 'Peters Jan'), 1),
#  (('Calandra Roberto', 'Rasmussen Carl Edward'), 1),
#  (('Calandra Roberto', 'Deisenroth Marc Peter'), 1),
#  (('Peters Jan', 'Rasmussen Carl Edward'), 1),
#  (('Peters Jan', 'Deisenroth Marc Peter'), 1),
#  (('Rasmussen Carl Edward', 'Deisenroth Marc Peter'), 1),
#  (('Yu Felix X.', 'Choromanski Krzysztof'), 2),
#  (('Yu Felix X.', 'Kumar Sanjiv'), 8),
#  (('Yu Felix X.', 'Jebara Tony'), 1),
#  (('Yu Felix X.', 'Chang Shih-Fu'), 2),
#  (('Choromanski Krzysztof', 'Kumar Sanjiv'), 3),
#  (('Choromanski Krzysztof', 'Jebara Tony'), 1),
#  (('Choromanski Krzysztof', 'Chang Shih-Fu'), 1),
#  (('Kumar Sanjiv', 'Jebara Tony'), 1),
#  (('Kumar Sanjiv', 'Chang Shih-Fu'), 2),
#  (('Jebara Tony', 'Chang Shih-Fu'), 1),
#  (('Flaounas Ilias', 'Lansdall-Welfare Thomas'), 1),
#  (('Flaounas Ilias', 'Antonakaki Panagiota'), 1),
#  (('Flaounas Ilias', 'Cristianini Nello'), 2),
#  (('Lansdall-Welfare Thomas', 'Antonakaki Panagiota'), 1),
#  (('Lansdall-Welfare Thomas', 'Cristianini Nello'), 3),
#  (('Antonakaki Panagiota', 'Cristianini Nello'), 1),
#  (('Morris Katherine', 'Punzo Antonio'), 1),
#  (('Morris Katherine', 'Browne Ryan P.'), 1),
#  (('Punzo Antonio', 'McNicholas Paul D.'), 2),
#  (('Punzo Antonio', 'Browne Ryan P.'), 2),
#  (('Kuipers Jack', 'Moffa Giusi'), 4),
#  (('Kuipers Jack', 'Heckerman David'), 1),
#  (('Moffa Giusi', 'Heckerman David'), 1),
#  (('Sitharam Meera', 'Tarifi Mohamad'), 1),
#  (('Sitharam Meera', 'Wang Menghan'), 1),
#  (('Tarifi Mohamad', 'Wang Menghan'), 1),
#  (('Zamani Mohammadzaman', 'Beigy Hamid'), 1),
#  (('Zamani Mohammadzaman', 'Shaban Amirreza'), 1),
#  (('Beigy Hamid', 'Shaban Amirreza'), 1),
#  (('Li Sanjiang', 'Long Zhiguo'), 1),
#  (('Li Sanjiang', 'Liu Weiming'), 1),
#  (('Li Sanjiang', 'Duckham Matt'), 1),
#  (('Li Sanjiang', 'Both Alan'), 1),
#  (('Long Zhiguo', 'Liu Weiming'), 1),
#  (('Long Zhiguo', 'Duckham Matt'), 1),
#  (('Long Zhiguo', 'Both Alan'), 1),
#  (('Liu Weiming', 'Duckham Matt'), 1),
#  (('Liu Weiming', 'Both Alan'), 1),
#  (('Duckham Matt', 'Both Alan'), 1),
#  (('Voss James', 'Belkin Mikhail'), 2),
#  ...]

# %%
weighted_author_edge_list = [(item[0][0], item[0][1], item[1]) for item in weighted_author_edge_list]
weighted_author_edge_list[:10]
# Out:
# [('Montanari Andrea', 'Ricci-Tersenghi Federico', 2),
#  ('Montanari Andrea', 'Semerjian Guilhem', 1),
#  ('Ricci-Tersenghi Federico', 'Semerjian Guilhem', 1),
#  ('Beygelzimer Alina', 'Langford John', 3),
#  ('Kuznetsov Sergei O.', 'Ignatov Dmitry I.', 1),
#  ('Blume Lawrence', 'Easley David', 1),
#  ('Blume Lawrence', 'Halpern Joseph Y.', 1),
#  ('Easley David', 'Halpern Joseph Y.', 1),
#  ('Kakade Sham M.', 'Shamir Ohad', 1),
#  ('Kakade Sham M.', 'Sridharan Karthik', 1)]

# %%
G = nx.Graph()
G.add_weighted_edges_from(weighted_author_edge_list)

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 114628
# Number of edges: 578484
# Average degree:  10.0932

# %%
sub_G = nx.subgraph(G, nodes_to_keep)
G = nx.Graph(sub_G)


print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 4287
# Number of edges: 29241
# Average degree:  13.6417

# %%
isolated_nodes = list(nx.isolates(G))
len(isolated_nodes)
# Out:
# 114

# %%
G.remove_nodes_from(isolated_nodes)
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 4173
# Number of edges: 29241
# Average degree:  14.0144

# %%
pyvis_network = Network(notebook=True, height = '600px', width = '100%', heading = 'Whole Co-Author Network')
pyvis_network.from_nx(G)
pyvis_network.show("whole.html")
# Out:
#         <iframe
#             width="100%"
#             height="600px"
#             src="whole.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## DeepWalk Algorithm

# %%
import random

# %%
def RandomWalk(graph, start_node, length_of_random_walk):
    
    current_node = start_node
    random_walk = [start_node]
    
    for i in range(length_of_random_walk):
        
        current_node_neighbors = list(graph.neighbors(current_node))
        chosen_node = random.choice(current_node_neighbors)
        current_node = chosen_node
        random_walk.append(current_node)
        
    return random_walk

# %%
from tqdm import tqdm

# %%
num_of_sampling = 10
random_walk_list = []
length_of_random_walk = 10

for node in tqdm(G.nodes(), desc = "Iterating Nodes"):
    for i in range(0, num_of_sampling):
        random_walk_list.append(RandomWalk(G, node, length_of_random_walk))
# Out:
# Iterating Nodes: 100%|███████████████████████████████████████████████████████████| 4173/4173 [00:00<00:00, 6161.92it/s]

# %%
from gensim.models.word2vec import Word2Vec

# %%
deepwalk_model = Word2Vec(sentences=random_walk_list, window=5, sg=1, negative=5, size=128, compute_loss=True)

# %%
deepwalk_model.save("deepwalk_since2015_gt10.model")

# %% [markdown]
# ## Similarity Analysis

# %%
deepwalk_model.wv.most_similar("Fei-Fei Li")
# Out:
# [('Niebles Juan Carlos', 0.8413130640983582),
#  ('Martín-Martín Roberto', 0.825070321559906),
#  ('Soto Alvaro', 0.817757248878479),
#  ('Piech Chris', 0.8129456639289856),
#  ('Xu Danfei', 0.7855753302574158),
#  ('Nair Suraj', 0.7797989845275879),
#  ('Bohg Jeannette', 0.7712190747261047),
#  ('Ren Hongyu', 0.761582612991333),
#  ('Manning Christopher D.', 0.7494522929191589),
#  ('Qureshi Ahmed H.', 0.7484649419784546)]

# %%
def getSimilarNodes(model, node):
    similarity = model.wv.most_similar(node)
    similar_nodes_df = pd.DataFrame()
    similar_nodes_df['similar_authors'] = [item[0] for item in similarity]
    similar_nodes_df['similarity_score'] = [item[1] for item in similarity]
    similar_nodes_df['source_author'] = node
    
    return similar_nodes_df

# %%
getSimilarNodes(deepwalk_model, "Fei-Fei Li")
# Out:
#           similar_authors  similarity_score source_author
# 0     Niebles Juan Carlos          0.841313    Fei-Fei Li
# 1   Martín-Martín Roberto          0.825070    Fei-Fei Li
# 2             Soto Alvaro          0.817757    Fei-Fei Li
# 3             Piech Chris          0.812946    Fei-Fei Li
# 4               Xu Danfei          0.785575    Fei-Fei Li
# 5              Nair Suraj          0.779799    Fei-Fei Li
# 6          Bohg Jeannette          0.771219    Fei-Fei Li
# 7              Ren Hongyu          0.761583    Fei-Fei Li
# 8  Manning Christopher D.          0.749452    Fei-Fei Li
# 9        Qureshi Ahmed H.          0.748465    Fei-Fei Li

# %% [markdown]
# ## CoAuthor Network Visualization

# %%
def getCoAuthorshipNetwork(graph, initial_nodes):
    count = 0
    nodes_list = [node for node in initial_nodes]
    
    for node in initial_nodes:
        neighbors = list(graph.neighbors(node))
        count += len(neighbors)
        nodes_list += neighbors
        
    return nodes_list

# %%
nodes_to_keep
# Out:
# {'Touati Ahmed',
#  'Kollias Dimitrios',
#  'Maheswaranathan Niru',
#  'Simeone Osvaldo',
#  'Yurochkin Mikhail',
#  'Liu Jixue',
#  'Choo Jaegul',
#  'Sheth Amit',
#  'Li Tianrui',
#  'Chen Yixin',
#  'Srivastava Biplav',
#  'Nagai Takayuki',
#  'Wang Qing',
#  'van Gerven Marcel',
#  'Javidi Tara',
#  "D'Amour Alexander",
#  'Caselles-Dupré Hugo',
#  'Ahn Sungjin',
#  'Russo Daniel',
#  'Liu Dong',
#  'Yip Michael C.',
#  'Li Jinyu',
#  'Liu Ming-Yu',
#  'Liu Lin',
#  'Chen Lei',
#  'Passerini Andrea',
#  'Yang Shuang',
#  'Chi Yuejie',
#  'Santos-Rodriguez Raul',
#  'Xu Jie',
#  'Yang Xin',
#  'Milli Smitha',
#  'Menon Aditya Krishna',
#  'Johansson Fredrik D.',
#  'Allen Genevera I.',
#  'Ling Qing',
#  'Saremi Saeed',
#  'Duan Yan',
#  'Wang Wenlin',
#  'Chandar Sarath',
#  'Benhamou Eric',
#  'Neykov Matey',
#  'Kumar Vikash',
#  'Marchisio Alberto',
#  'Kuang Kun',
#  'Driggs-Campbell Katherine',
#  'Evans David',
#  'Vehtari Aki',
#  'Shang Fanhua',
#  'Huang Yu',
#  'Vaswani Namrata',
#  'Chernova Sonia',
#  'Jaderberg Max',
#  'Kira Zsolt',
#  'Wang Yunlong',
#  'Wang Xianzhi',
#  'Wu Qiang',
#  'Ghoshdastidar Debarghya',
#  'Li Bin',
#  'Wang Jian',
#  'Blanchet Jose',
#  'Zheng Nanning',
#  'Fredrikson Matt',
#  'Ong Desmond C.',
#  'Yang Yiming',
#  'Chamberlain Benjamin Paul',
#  'Moreno Ignacio Lopez',
#  'Vandermeulen Robert A.',
#  'Schüller Peter',
#  'Pan Shirui',
#  'Teytaud Olivier',
#  'Restelli Marcello',
#  'Kepner Jeremy',
#  'Kosiorek Adam R.',
#  'Koren Tomer',
#  'Walsh Toby',
#  'Ebrahimi Sayna',
#  'Mossel Elchanan',
#  'Wang Qi',
#  'Zhao Ding',
#  'Kasneci Gjergji',
#  'Schreurs Joachim',
#  'Li Zhenhui',
#  'Tomizuka Masayoshi',
#  'Zhang Amy',
#  'Yan Ming',
#  'Malach Eran',
#  'Tan Mingkui',
#  'Wolter Frank',
#  'Lee Jason D.',
#  'Lindsten Fredrik',
#  'Hang Hanyuan',
#  'Zhou Xin',
#  'Zhao Pu',
#  'Belle Vaishak',
#  'Ghasemzadeh Hassan',
#  'Vollgraf Roland',
#  'Neelakantan Arvind',
#  'Zhang Yue',
#  'Da Xu Richard Yi',
#  'Wang Hsin-Min',
#  'Zhou Tianyi',
#  'Niyato Dusit',
#  'Suresh Ananda Theertha',
#  'Xing Eric P.',
#  'Phan Huy',
#  'Zhang Fuzheng',
#  'Chiu Chung-Cheng',
#  'Ho Nhat',
#  'Oates Tim',
#  'Zhu Rui',
#  'Sun Liting',
#  'Zhu Jun-Yan',
#  'Mozer Michael C.',
#  'Avron Haim',
#  'Koehler Frederic',
#  'Ammanabrolu Prithviraj',
#  'Yin Wotao',
#  'Chen Yu',
#  'Berkenkamp Felix',
#  'Dunson David B.',
#  'He Xiangnan',
#  'Simonyan Karen',
#  'Li Chunyuan',
#  'Sharma Yash',
#  'Yu Chao',
#  'Battaglia Peter',
#  'Foo Chuan-Sheng',
#  'Liu Hui',
#  'Orseau Laurent',
#  'Ghosh Soumya',
#  'Martín-Martín Roberto',
#  'Pedram Massoud',
#  'Munawar Asim',
#  'Schekotihin Konstantin',
#  'Wei Peng',
#  'Fookes Clinton',
#  'Bo Liefeng',
#  'Bischl Bernd',
#  'Alviano Mario',
#  'Zhou Zhiming',
#  'Song Rui',
#  'Niculae Vlad',
#  'Salim Flora D.',
#  'van der Laan Mark J.',
#  'Tschantz Alexander',
#  'Smith Samuel L.',
#  'Blondel Mathieu',
#  'Liu Bo',
#  'Glymour Clark',
#  'Darrell Trevor',
#  'Fan Changjie',
#  'Lim Bryan',
#  'Tan Chenhao',
#  'Schmid Cordelia',
#  'Luo Rui',
#  'Nakov Preslav',
#  'Mouret Jean-Baptiste',
#  'Magdon-Ismail Malik',
#  'Saria Suchi',
#  'Xing Eric',
#  'Zhang Huishuai',
#  'Zhou Fan',
#  'Stich Sebastian U.',
#  'Laugel Thibault',
#  'Hupkes Dieuwke',
#  'Balcan Maria-Florina',
#  'Muñoz-González Luis',
#  'Maeda Shin-ichi',
#  'Rokach Lior',
#  'Oltean Mihai',
#  'Kreutzer Julia',
#  'Ru Binxin',
#  'Gabrys Bogdan',
#  'Peters Jan',
#  'Iyer Rishabh',
#  'Athey Susan',
#  'De Bie Tijl',
#  'Lin Bill Yuchen',
#  'Ho Jonathan',
#  'Mitra Bhaskar',
#  'Qing Huan',
#  'Le Quoc',
#  'Fu Justin',
#  'Melnyk Igor',
#  'Le Trung',
#  'Yu Haonan',
#  'Swami Ananthram',
#  'Kanoulas Evangelos',
#  'Vahdat Arash',
#  'Cui Lizhen',
#  'Kosorok Michael R.',
#  'Serra Xavier',
#  'Chen Xin',
#  'Inatsu Yu',
#  'Weihs Luca',
#  'Gentile Claudio',
#  'Couillet Romain',
#  'Wang Jianmin',
#  'Raitoharju Jenni',
#  'Tessler Chen',
#  'Cummings Rachel',
#  'Kleinberg Jon',
#  'Su Hang',
#  'Sperduti Alessandro',
#  'Li Xiujun',
#  'Rieck Bastian',
#  'Kuhn Daniel',
#  'Gallicchio Claudio',
#  'Zhou Pan',
#  'Tao Dacheng',
#  'La Rosa Marcello',
#  'Shekhovtsov Alexander',
#  'Narayanamurthy Praneeth',
#  'Noé Frank',
#  'Farquhar Sebastian',
#  'Sun Lichao',
#  'Zhang Nevin L.',
#  'Vakili Sattar',
#  'Ostrovski Georg',
#  'Balakrishnan Sivaraman',
#  'Tabor Jacek',
#  'Domeniconi Carlotta',
#  'Nie Feiping',
#  'Frank Eibe',
#  'McGuinness Deborah L.',
#  'Ma Xiao',
#  'Monti Ricardo Pio',
#  'Barnes Laura E.',
#  'Zhang Teng',
#  'Yang Xiao',
#  'Sukhatme Gaurav',
#  'Kavukcuoglu Koray',
#  'Heller Katherine',
#  'Poli Michael',
#  'Dann Christoph',
#  'Jamnik Mateja',
#  'Yang Yibo',
#  'Hammer Barbara',
#  'Xiao Jun',
#  'Amodei Dario',
#  'Park Jinkyoo',
#  'Huang Gao',
#  'Poczos Barnabas',
#  'Ganapathysubramanian Baskar',
#  'Yu Yi',
#  'Cochez Michael',
#  'Pedregosa Fabian',
#  'Shakkottai Sanjay',
#  'Belanger David',
#  'Bouneffouf Djallel',
#  'Zettlemoyer Luke',
#  'Radev Dragomir',
#  'Rong Yu',
#  'Bernardino Alexandre',
#  'Atia George',
#  'Zhang Yunfeng',
#  'Langford John',
#  'Xu Chang',
#  'Oberhauser Harald',
#  'Zhu Ye',
#  'Kannan Sreeram',
#  'Vert Jean-Philippe',
#  'Scheinberg Katya',
#  'Jenssen Robert',
#  'Shui Changjian',
#  'Ni Bingbing',
#  'van der Smagt Patrick',
#  'Huo Zhouyuan',
#  'Hansen Lars Kai',
#  'Fujimura Kikuo',
#  'Xie Cong',
#  'Scaglione Anna',
#  'Sukhatme Gaurav S.',
#  'Hanneke Steve',
#  'Simchowitz Max',
#  'Zaffalon Marco',
#  'Kaliszyk Cezary',
#  'Alemi Alexander A.',
#  'Sankar Chinnadhurai',
#  'Bajwa Waheed U.',
#  'Shrivastava Anshumali',
#  'Zhu Hongtu',
#  'Wang Yue',
#  'Fort Stanislav',
#  'Dhoedt Bart',
#  'Zhang Weinan',
#  'Yu Dong',
#  'Khalid Faiq',
#  'Levy Kfir Y.',
#  'Eggensperger Katharina',
#  'Zhang Lei',
#  'Vishnoi Nisheeth K.',
#  'Tripuraneni Nilesh',
#  'Garg Animesh',
#  'Choudhury Sanjiban',
#  'Dasarathy Gautam',
#  'Kingma Diederik P.',
#  'Fu Qiang',
#  'Mastrogiovanni Fulvio',
#  'Guo Xin',
#  'Hamilton William L.',
#  'Williamson Sinead A.',
#  'Chen Kai',
#  'Li Yang',
#  'Chen Di',
#  'Bagnall Anthony',
#  'Han Bohyung',
#  'King Irwin',
#  'Bradic Jelena',
#  'Zheng Kai',
#  'Ma Chao',
#  'Yeung Dit-Yan',
#  'Sun Xu',
#  'Eriksson David',
#  'Ooi Beng Chin',
#  'Akata Zeynep',
#  'Hernández-Lobato José Miguel',
#  'Dong Xiaowen',
#  'Swersky Kevin',
#  'Zhao Qi',
#  'Qiu Qinru',
#  'Nealen Andy',
#  'Ioannidis Vassilis N.',
#  'Yousefnezhad Muhammad',
#  'Thananjeyan Brijen',
#  'Monga Vishal',
#  'Kang Zhao',
#  'Rybkin Oleh',
#  'Yang Liu',
#  'Imaizumi Masaaki',
#  'Nguyen Lam M.',
#  'Xu Zhongwen',
#  'Meng Max Q. -H.',
#  'Tewari Ambuj',
#  'Tsang Ivor',
#  'Seshia Sanjit A.',
#  'Hassani Hamed',
#  'Bauer Stefan',
#  'Li Xuelong',
#  'Voloshynovskiy Slava',
#  'Perozzi Bryan',
#  'Liu Xiao',
#  'Zou James',
#  'Roijers Diederik M.',
#  'Montufar Guido',
#  'Snoek Jasper',
#  'Zhang Kaiqing',
#  'Hosseini Reshad',
#  'Xu Hang',
#  'Niekum Scott',
#  'Tyagi Hemant',
#  'Song Qingquan',
#  'Yu Philip S.',
#  'Liu Tie-Yan',
#  'Klakow Dietrich',
#  'Mannelli Stefano Sarao',
#  'Chaudhuri Kamalika',
#  'Elgammal Ahmed',
#  'Reddy Chandan K.',
#  'Wang Qian',
#  'Dai Zihang',
#  'Silva Ricardo',
#  'Kuzelka Ondrej',
#  'Kutyniok Gitta',
#  'Brown Donald E.',
#  'Zaharia Matei',
#  'Ma Cong',
#  'Yousef Waleed A.',
#  'Wang Shusen',
#  'Chatterjee Krishnendu',
#  'Singla Parag',
#  'Durrett Greg',
#  'Yang Ming-Hsuan',
#  'Iwata Tomoharu',
#  'Liu Wei',
#  'Tran Co',
#  'Filippone Maurizio',
#  'Leyton-Brown Kevin',
#  'Schockaert Steven',
#  'Sra Suvrit',
#  'Aila Timo',
#  'Pande Vijay S.',
#  'Chamroukhi Faicel',
#  'Karatzoglou Alexandros',
#  'Salmon Joseph',
#  'Woltran Stefan',
#  'Tesauro Gerald',
#  'Tan Hao',
#  'Liu Sheng',
#  'Huang Wenbing',
#  'Nasrabadi Nasser M.',
#  'Shah Nihar B.',
#  'Feng Jiashi',
#  'Wang Chong',
#  'Chen Jie',
#  'Sriperumbudur Bharath K.',
#  'Hartley Richard',
#  'Bauckhage Christian',
#  'Wang Haifeng',
#  'Azizzadenesheli Kamyar',
#  'Kondor Risi',
#  'Li Mu',
#  'Lipson Hod',
#  'Yu Tianhe',
#  'Śmieja Marek',
#  'Wang Xuezhi',
#  'Hessel Matteo',
#  'Dillon Joshua V.',
#  'Geiger Mario',
#  'Vosoughi Soroush',
#  'Zhou Bo',
#  'Yang Greg',
#  'Günnemann Stephan',
#  'Ying Lexing',
#  'Osband Ian',
#  'Gomez-Rodriguez Manuel',
#  'Fan Jianqing',
#  'Paquet Ulrich',
#  'Burgard Wolfram',
#  'Zhang Ying',
#  'Tenenbaum Joshua B.',
#  'Wang Gang',
#  'Chen Xinyun',
#  'Ha Jung-Woo',
#  'Dunjko Vedran',
#  'Carlson David',
#  'Trigoni Niki',
#  'Gramfort Alexandre',
#  'Fox Emily B.',
#  'Wang Lei',
#  'He Xiuqiang',
#  'Spiliopoulos Konstantinos',
#  'Evans Owain',
#  'Garrido-Merchán Eduardo C.',
#  'Pentland Alex',
#  'Gao Weihao',
#  'Titsias Michalis K.',
#  'Dong Bin',
#  'Zhang Yongfeng',
#  'Madotto Andrea',
#  'Everitt Tom',
#  'Yu Hwanjo',
#  'Brown Noam',
#  'Liu C. Karen',
#  'Deng Jia',
#  'Mahloujifar Saeed',
#  'Celikyilmaz Asli',
#  'Faloutsos Christos',
#  'Kochenderfer Mykel',
#  'Liu Chang',
#  'Yang Cheng',
#  'Särkkä Simo',
#  'Siddharth N.',
#  'Isupova Olga',
#  'Hochreiter Sepp',
#  'Kim Byungsoo',
#  'Aloimonos Yiannis',
#  'Barratt Shane',
#  'Wang Shiqiang',
#  'Bartz-Beielstein Thomas',
#  'Paxton Chris',
#  'Lyons Terry',
#  'Lee Hung-yi',
#  'Grohs Philipp',
#  'Matteson David S.',
#  'von Kügelgen Julius',
#  'Yu Zhiding',
#  'Gel Yulia R.',
#  'White Colin',
#  'Ramchandran Kannan',
#  'Donini Michele',
#  'Rashidi Parisa',
#  'Manwani Naresh',
#  'Stumme Gerd',
#  'Qi Yanjun',
#  'De Cao Nicola',
#  'Harchaoui Zaid',
#  'Wright John',
#  'Kumar Aviral',
#  'Gokcesu Kaan',
#  'Nock Richard',
#  'Blei David M.',
#  'Mansinghka Vikash K.',
#  'Perrone Valerio',
#  'Bailis Peter',
#  'Szegedy Christian',
#  'Wang Mei-Hui',
#  'Yan Shuicheng',
#  'Williams Brian C.',
#  'Ke Nan Rosemary',
#  'Ishikawa Isao',
#  'Tibshirani Ryan J.',
#  'Lu Zongqing',
#  'Le Hung',
#  'Wang Ping',
#  'Pajarinen Joni',
#  'Qureshi Ahmed H.',
#  'Rawat Ankit Singh',
#  'Calmon Flavio P.',
#  'Dwivedi Raaz',
#  'Bacon Pierre-Luc',
#  'Cohen Joseph Paul',
#  'Scardapane Simone',
#  'Pang Tianyu',
#  'David Eli',
#  'Shin Jinwoo',
#  'Joshi Shalmali',
#  'Cheng Guang',
#  'Hofmann Katja',
#  'Combes Richard',
#  'Li Chongxuan',
#  'Mukhopadhyay Saibal',
#  'Sun Wei',
#  'Baydin Atılım Güneş',
#  'Chen Samuel Yen-Chi',
#  'Hajishirzi Hannaneh',
#  'Chen Jiaoyan',
#  'Raissi Maziar',
#  'Gupta Vivek',
#  'Bahri Yasaman',
#  'Wei Dennis',
#  'Cavalcanti George D. C.',
#  'Kanai Ryota',
#  'Pedapati Tejaswini',
#  'He Xin',
#  'Chang Shiyu',
#  'Zadeh Amir',
#  'Li Wenjie',
#  'Courville Aaron',
#  'Sudjianto Agus',
#  'Zhan Wei',
#  'Duy Vo Nguyen Le',
#  'Geirhos Robert',
#  'Adlam Ben',
#  'Wang Fei',
#  'Yuan Yang',
#  'Chen Ying',
#  'Liu Teng',
#  'Trapp Martin',
#  'Frazier Peter I.',
#  'Johansson Mikael',
#  'Abid Abubakar',
#  'Smith Virginia',
#  'Awasthi Pranjal',
#  'Weichwald Sebastian',
#  'Zhang Lijun',
#  'Adams Ryan P.',
#  'Hadjeres Gaëtan',
#  'Roy Kaushik',
#  'George Dileep',
#  'De Abir',
#  'Li Yu',
#  'McCallum Andrew',
#  'Kinnunen Tomi',
#  'Zhu Yi',
#  'Hsu Wei-Ning',
#  'Hu Han',
#  'Tang Shaojie',
#  'Grossglauser Matthias',
#  'Vempala Santosh S.',
#  'Zhang Dongmei',
#  'Luo Jiebo',
#  'Lacoste Alexandre',
#  'Hutter Marcus',
#  'Singer Yoram',
#  'Zhao Tong',
#  'Jayaraman Dinesh',
#  'Marasek Krzysztof',
#  'Boyd Stephen',
#  'Ji Kaiyi',
#  'Salehkaleybar Saber',
#  'Jia Ruoxi',
#  'Wu Yuhuai',
#  'Mitchell Tom',
#  'Xie Pengtao',
#  'Smith Jim Q.',
#  'Kaplan Haim',
#  'Li Tian',
#  'Fiorino Humbert',
#  'Lu Jiwen',
#  'Guns Tias',
#  'Lazaric Alessandro',
#  'Wang Bo',
#  'Farokhi Farhad',
#  'Jha Somesh',
#  'Yang Yi-Hsuan',
#  'Bunel Rudy',
#  'Blockeel Hendrik',
#  'Liò Pietro',
#  'Sun Hao',
#  'Guo Hongyu',
#  'Song Yang',
#  'Xia Shu-Tao',
#  'Shafto Patrick',
#  'Alippi Cesare',
#  'Meng Zhong',
#  'Willett Rebecca',
#  'Wong Kam-Fai',
#  'Xu Fangli',
#  'Yu Zhou',
#  'Udluft Steffen',
#  'Peltola Tomi',
#  'Neyshabur Behnam',
#  'Wang Zhiguo',
#  'Bhatnagar Shalabh',
#  'Aerts Diederik',
#  'Ricca Francesco',
#  'Lederer Johannes',
#  'Hajij Mustafa',
#  'Li Zhao',
#  'Niethammer Marc',
#  'Pande Vijay',
#  'Dilkina Bistra',
#  'Wolff J Gerard',
#  'Hoydis Jakob',
#  'Thomas Philip S.',
#  'He Chaoyang',
#  'Yannakakis Georgios N.',
#  'Jiang Daxin',
#  'Feuerriegel Stefan',
#  'Xu Ji',
#  'Meng Fandong',
#  'Hyvärinen Aapo',
#  'Gretton Arthur',
#  'Zhou Bowen',
#  'Jansen Nils',
#  'Rodriguez Manuel Gomez',
#  'Guo Jun',
#  'Wong Eric',
#  'Saligrama Venkatesh',
#  'Zhang Yu',
#  'Pereira Ramon Fraga',
#  'Han Jungong',
#  'Suk Heung-Il',
#  'Jin Wei',
#  'Dohmatob Elvis',
#  'Zhu Rong',
#  'Ma Hang',
#  'Meger David',
#  'Soltani Mohammadreza',
#  'Zhou Joey Tianyi',
#  'Park Jihong',
#  'Dou Dejing',
#  'Xue Yexiang',
#  'Li Jerry',
#  'Wayne Greg',
#  'Bonet Blai',
#  'Ravindran Balaraman',
#  'Biggio Battista',
#  'Detyniecki Marcin',
#  'Li Zhe',
#  'Kailkhura Bhavya',
#  'Trischler Adam',
#  'Cai T. Tony',
#  'Xue Lingzhou',
#  'Wachinger Christian',
#  'Kulis Brian',
#  'Zhang Shanghang',
#  'Chen Long',
#  'Zhang Yang',
#  'Veličković Petar',
#  'Zhu Kenny Q.',
#  'Wang Yuyi',
#  'Konukoglu Ender',
#  'Meneguzzi Felipe',
#  'Brendel Wieland',
#  'Yi Jinfeng',
#  'Song Le',
#  'Ikeda Masahiro',
#  'Oh Sewoong',
#  'Molina Alejandro',
#  'Feldman Dan',
#  'Kim Edward',
#  'Lee Su-In',
#  'Zhang Yuan',
#  'Ghosh Joydeep',
#  'Li Yan',
#  'Taylor Matthew E.',
#  'Liu Fanghui',
#  'Balaprakash Prasanna',
#  'Wang Yixin',
#  'Lucas Simon M.',
#  'Behzadan Vahid',
#  'Minervini Pasquale',
#  'Chen Zhengzhang',
#  'Hein Matthias',
#  'Burnaev Evgeny',
#  'Krijthe Jesse H.',
#  'Cho Kyunghyun',
#  'Martin Arnaud  IRISA',
#  'Lyzinski Vince',
#  'Lamprier Sylvain',
#  'Aravkin Aleksandr Y.',
#  'Gutmann Michael U.',
#  'Wang Shuohang',
#  'Wulfmeier Markus',
#  'Eppe Manfred',
#  'Sarker Iqbal H.',
#  'Forestier Germain',
#  'Villani Mattias',
#  'Titov Ivan',
#  'Pritzel Alexander',
#  'Zhou Ming',
#  'Kanan Christopher',
#  'Kejriwal Mayank',
#  'Peñaloza Rafael',
#  'Eysenbach Benjamin',
#  'Hron Jiri',
#  'Zhao Dongbin',
#  'Ramazzotti Daniele',
#  'Savvides Marios',
#  'Lutz Carsten',
#  'Ranganath Rajesh',
#  'Sarkar Purnamrita',
#  'Chen Zhifeng',
#  'Durand Audrey',
#  'Batra Dhruv',
#  'Gupta Maya',
#  'Riquelme Carlos',
#  'Nowak Robert D.',
#  'Gupta Sunil',
#  'Malinin Andrey',
#  'Chen Xi',
#  'Celli Andrea',
#  'Prabhat',
#  'Xie Jianwen',
#  'Swaminathan Adith',
#  'Hennequin Romain',
#  'Lin Guang',
#  'Hitzler Pascal',
#  'Kabashima Yoshiyuki',
#  'Rai Piyush',
#  'Ying Rex',
#  'Zemel Richard',
#  'Shen Tao',
#  'Hamrick Jessica B.',
#  'Bi Jinbo',
#  'Jaakkola Tommi S.',
#  'Hendrycks Dan',
#  'Li Tao',
#  'Storkey Amos',
#  'Razaviyayn Meisam',
#  'Smeaton Alan F.',
#  'Wang Zihao',
#  'Sun Yuekai',
#  'Fletcher Alyson K.',
#  'Khan Usman A.',
#  'Chen Yudong',
#  'Black Alan W',
#  'Kamath Gautam',
#  'Singla Adish',
#  'Sun Will Wei',
#  'Pechenizkiy Mykola',
#  'Welleck Sean',
#  'Yue Yisong',
#  'Hengel Anton van den',
#  'Tassa Yuval',
#  'Bruni Elia',
#  'Narasimhan Harikrishna',
#  'Khan Mohammad Emtiyaz',
#  'Başar Tamer',
#  'Madhow Upamanyu',
#  'Napoli Amedeo',
#  'Binder Alexander',
#  'Yang Kai',
#  'Bu Yuheng',
#  'Holzinger Andreas',
#  'Fessler Jeffrey A.',
#  'Beel Joeran',
#  'Gupta Rahul',
#  'Honkela Antti',
#  'Li Guoqi',
#  'Lopez-Paz David',
#  'Su Qinliang',
#  'Song Guojie',
#  'Sun Lijun',
#  'Finlay Chris',
#  'Dickerson John P.',
#  'Garnett Roman',
#  'He Xiaodong',
#  'Wang Guoyin',
#  'Lu Yang',
#  'Doran Derek',
#  'Agirre Eneko',
#  'Zhu Quanyan',
#  'Quek Tony Q. S.',
#  'Morris Christopher',
#  'Karami Amir',
#  'Qi Jianzhong',
#  'Gholami Amir',
#  'Saenko Kate',
#  'Glocker Ben',
#  'Faust Aleksandra',
#  'Kpotufe Samory',
#  'Grauman Kristen',
#  'Feng Yang',
#  'Gaina Raluca D.',
#  'Gori Pietro',
#  'Shaham Uri',
#  'Chen Ningyuan',
#  'Van Gool Luc',
#  'Koyama Masanori',
#  'Protopapas Pavlos',
#  'Wang Bin',
#  'Deligiannis Nikos',
#  'Clark Peter',
#  'Ultes Stefan',
#  'Bronstein Michael M.',
#  'Li Fan',
#  'Li Shuai',
#  'Szabo Zoltan',
#  'Schaus Pierre',
#  'Zhang Pengchuan',
#  'Schütt Kristof T.',
#  'Guo Xiaoxiao',
#  'Parnell Thomas',
#  'Del Ser Javier',
#  'Li Qianxiao',
#  'Milford Michael',
#  'Ramamurthy Karthikeyan Natesan',
#  'Li Jundong',
#  'Takeishi Naoya',
#  'Yin Hongzhi',
#  'Zhang Chicheng',
#  'Pantic Maja',
#  'Pietquin Olivier',
#  'Li Zheng',
#  'Wang Yunhe',
#  'Graves Daniel',
#  'Zhang Aston',
#  'Seita Daniel',
#  'Liu Xiaodong',
#  'Karkus Peter',
#  'Mazoure Bogdan',
#  'Gama Fernando',
#  'Karypis George',
#  'Nakajima Shinichi',
#  'Zhou Kaiwen',
#  'Tadepalli Prasad',
#  'Ahmed Nesreen K.',
#  'Daumé Hal III',
#  'Krishnamurthy Akshay',
#  'Gal Yarin',
#  'Veeramachaneni Kalyan',
#  'Maratea Marco',
#  'Tan Jie',
#  'Wu Qi',
#  'Yuan Ye',
#  'Caramanis Constantine',
#  'Chernozhukov Victor',
#  'Kachuee Mohammad',
#  'Bruna Joan',
#  'Agarwal Naman',
#  'Dietterich Thomas G.',
#  'You Chong',
#  'Cosgun Akansel',
#  'Erdem Esra',
#  'Wang Yang',
#  'Lughofer Edwin',
#  'Aziz Haris',
#  'Littman Michael L.',
#  'Bing Lidong',
#  'Briol François-Xavier',
#  'Choshen Leshem',
#  'Gasthaus Jan',
#  'Wu Fan',
#  'Ma Yi',
#  'Guibas Leonidas',
#  'Rajpurkar Pranav',
#  "O'Reilly Una-May",
#  'Laradji Issam',
#  'Shi Yiyu',
#  'Amato Christopher',
#  'Hsu Daniel',
#  'Ho Mark K.',
#  'Huang Siyuan',
#  'Li Kai',
#  'Szolovits Peter',
#  'Clémençon Stéphan',
#  'Jang Eric',
#  'Chen Cheng',
#  'Ma Yunpu',
#  'Augenstein Isabelle',
#  'Wei Ying',
#  'Chen Weizhu',
#  'De Soham',
#  'van der Wilk Mark',
#  'Li Xu',
#  'Racanière Sébastien',
#  'Liu Ji',
#  'Betti Alessandro',
#  'Wen Ying',
#  'Ghahramani Zoubin',
#  'Sato Issei',
#  'Zhang Chi',
#  'Ziel Florian',
#  'Xu Bo',
#  'Jamieson Kevin',
#  'Gan Chuang',
#  'Rossi Ryan A.',
#  'Phung Dinh',
#  'Loy Chen Change',
#  'Tsuruoka Yoshimasa',
#  'Huang Kaizhu',
#  'Huang Weiran',
#  'Livni Roi',
#  'Kakade Sham M.',
#  "d'Aspremont Alexandre",
#  'Huang Haiping',
#  'Guo Jiafeng',
#  'Jha Niraj K.',
#  'Fu Xiao',
#  'Stanley Kenneth O.',
#  'Rehg James M.',
#  'Metzen Jan Hendrik',
#  'Goodman Noah D.',
#  'Dinan Emily',
#  'Singh Rita',
#  'Doucet Arnaud',
#  'Zhao Tiancheng',
#  'Lapuschkin Sebastian',
#  'Yan Feng',
#  'Piot Bilal',
#  'Buettner Florian',
#  'Buhmann Joachim M.',
#  'Sen Rajat',
#  'Ma Jian',
#  'Li Zhenguo',
#  'Rodrigues Filipe',
#  'Higgins Irina',
#  'Zheng Yan',
#  'Wang Yisen',
#  'Sohl-Dickstein Jascha',
#  'Bellemare Marc G.',
#  'Ding Guiguang',
#  'Liu Lei',
#  'Li Xiao',
#  'Claassen Tom',
#  'Ha Sehoon',
#  'Shu Tianmin',
#  'Gurevych Iryna',
#  'Park Mijung',
#  'Huang Biwei',
#  'Sozzo Sandro',
#  'Montanari Andrea',
#  'Sordoni Alessandro',
#  'Kazemi Seyed Mehran',
#  'Perez Ethan',
#  'Chu Wei',
#  'Parikh Devi',
#  'Moyer Daniel',
#  'Li Yuanzhi',
#  'Karimi Amir-Hossein',
#  'Mertins Alfred',
#  'Zilberstein Shlomo',
#  'Scott Clayton',
#  'Steurer David',
#  'Yih Wen-tau',
#  'Akoglu Leman',
#  'Bandeira Afonso S.',
#  'Woodruff David P.',
#  'Zhang Jing',
#  'Amatriain Xavier',
#  'Gao Yuan',
#  'Wang Xinyu',
#  'Krishna Gautam',
#  'Colombo Pierre',
#  'Dieng Adji B.',
#  'Shi Yong',
#  'Jin Junqi',
#  'Ramdas Aaditya',
#  'Deshpande Amit',
#  'Paschalidis Ioannis Ch.',
#  'Allen Carl',
#  'Wang Kun',
#  'Ghanem Bernard',
#  'Sharma Mohit',
#  'Socher Richard',
#  'Zhou Dongruo',
#  'Huang Kejun',
#  'Zhan Jianfeng',
#  'Cucuringu Mihai',
#  'Pan Wei',
#  'Stoica Ion',
#  'Ying Yiming',
#  'Halpern Joseph Y.',
#  'Khan Shujaat',
#  'White Martha',
#  'Lin Xue',
#  'Jastrzębski Stanisław',
#  'Kumar T. K. Satish',
#  'Papailiopoulos Dimitris',
#  'Marvasti Farokh',
#  'Xiong Haoyi',
#  'Serban Iulian Vlad',
#  'Ahuja Kartik',
#  'Tsotsos John K.',
#  'Levine Sergey',
#  'Amini Arash A.',
#  ...}

# %%
paper_count_by_author.most_common(20)
# Out:
# [('Bengio Yoshua', 216),
#  ('Levine Sergey', 216),
#  ('Abbeel Pieter', 162),
#  ('Jordan Michael I.', 157),
#  ('Schölkopf Bernhard', 139),
#  ('Liu Yang', 136),
#  ('Sugiyama Masashi', 132),
#  ('Wang Jun', 114),
#  ('Carin Lawrence', 112),
#  ('Welling Max', 111),
#  ('Li Bo', 106),
#  ('Ermon Stefano', 105),
#  ('Krause Andreas', 104),
#  ('Zhu Jun', 104),
#  ('Mannor Shie', 100),
#  ('Tao Dacheng', 93),
#  ('Gu Quanquan', 93),
#  ('Salakhutdinov Ruslan', 92),
#  ('Teh Yee Whye', 91),
#  ('Chen Pin-Yu', 91)]

# %%
coauthor_nodes = getCoAuthorshipNetwork(G, ['Bengio Yoshua', 'Fei-Fei Li', 'Teh Yee Whye'])

# %%
len(coauthor_nodes)
# Out:
# 273

# %%
len(set(coauthor_nodes))
# Out:
# 262

# %%
coauthor_subgraph = nx.subgraph(G, coauthor_nodes)
print(nx.info(coauthor_subgraph))
# Out:
# Name:
# Type: Graph
# Number of nodes: 262
# Number of edges: 1952
# Average degree:  14.9008

# %%
import pyvis

# %%
from pyvis.network import Network

# %%
pyvis_network = Network(notebook=True, height = '600px', width = '100%', heading = 'Co-Author Network of Fei-Fei Li')
pyvis_network.from_nx(coauthor_subgraph)
pyvis_network.show("Fei-Fei_Li.html")
# Out:
#         <iframe
#             width="100%"
#             height="600px"
#             src="Fei-Fei_Li.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
coauthor_embeddings = np.zeros((len(coauthor_nodes), 128))
for idx, node in enumerate(coauthor_nodes):
    coauthor_embeddings[idx, :] = deepwalk_model.wv[node]
coauthor_embeddings.shape
# Out:
# (643, 128)

# %%
from sklearn.metrics.pairwise import cosine_distances

# %%
pairwise_cosine_similarity = cosine_distances(coauthor_embeddings)
pairwise_cosine_similarity.shape
# Out:
# (643, 643)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.cluster import KMeans

# %%
kmeans_model = KMeans(n_clusters=3)
coauthor_clusters = kmeans_model.fit_predict(pairwise_cosine_similarity)
print(kmeans_model.inertia_)
# Out:
# 4265.678902368664

# %%
coauthor_cluster_dict = {node: str(coauthor_clusters[idx]) for idx, node in enumerate(coauthor_nodes)}

# %%
nx.set_node_attributes(coauthor_subgraph, coauthor_cluster_dict, "group")

# %%
pyvis_network = Network(notebook=True, height='800px', width='100%', heading = 'Author Network Clustering Effects')
pyvis_network.from_nx(coauthor_subgraph)
pyvis_network.toggle_physics(True)
pyvis_network.show("clustering.html")
# Out:
#         <iframe
#             width="100%"
#             height="800px"
#             src="clustering.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
fei_coauthor_nodes = getCoAuthorshipNetwork(G, ['Bengio Yoshua'])
fei_network = nx.subgraph(G, fei_coauthor_nodes)
print(nx.info(fei_network))
# Out:
# Name:
# Type: Graph
# Number of nodes: 344
# Number of edges: 2213
# Average degree:  12.8663

# %%
pyvis_network = Network(notebook=True, height='800px', width='100%', heading = 'Fei-Fei Li Author Network Clustering Effects')
pyvis_network.from_nx(fei_network)
pyvis_network.toggle_physics(True)
pyvis_network.show("fei_clustering.html")
# Out:
#         <iframe
#             width="100%"
#             height="800px"
#             src="fei_clustering.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
